# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Загрузка данных

# %%
df = pd.read_csv("StudentPerformanceFactors.csv")

# %%
df.head()
# Out:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                         No            7               73              Low
# 1                         No            8               59              Low
# 2                        Yes            7               91           Medium
# 3                        Yes            8               98           Medium
# 4                        Yes            6               65           Medium
#
#   Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0             Yes                  0           Low          Medium
# 1             Yes                  2        Medium          Medium
# 2             Yes                  2        Medium          Medium
# 3             Yes                  1        Medium          Medium
# 4             Yes                  3        Medium            High
#
#   School_Type Peer_Influence  Physical_Activity Learning_Disabilities  \
# 0      Public       Positive                  3                    No
# 1      Public       Negative                  4                    No
# 2      Public        Neutral                  4                    No
# 3      Public       Negative                  4                    No
# 4      Public        Neutral                  4                    No
#
#   Parental_Education_Level Distance_from_Home  Gender  Exam_Score
# 0              High School               Near    Male          67
# 1                  College           Moderate  Female          61
# 2             Postgraduate               Near    Male          74
# 3              High School           Moderate    Male          71
# 4                  College               Near  Female          70

# %% [markdown]
# ### Описание данных

# %% [markdown]
# - **Hours_Studied (Часы_изучения)** - Количество часов, затрачиваемых на учебу в неделю.
# - **Attendance (Посещаемость)** - Процент посещенных занятий.
# - **Parental_Involvement (Родительское_участие)** - Уровень участия родителей в образовании учащегося (низкий, средний, высокий).
# - **Access_to_Resources (Доступ_к_ресурсам)** -	Доступность образовательных ресурсов (низкая, средняя, ​​высокая).
# - **Extracurricular_Activities (Внеклассные_мероприятия)** -	Участие во внеклассных мероприятиях (Да, Нет).
# - **Sleep_Hours (Часы_сна)** - Среднее количество часов сна за ночь.
# - **Previous_Scores (Предыдущие_результаты)** - Результаты предыдущих экзаменов.
# - **Motivation_Level (Уровень_мотивации)** -	Уровень мотивации студента (низкий, средний, высокий).
# - **Internet_Access (Интернет_доступ)** - Наличие доступа в Интернет (Да, Нет).
# - **Tutoring_Sessions (Репетиторство_Сессии)** - Количество посещенных занятий в месяц.
# - **Family_Income (Семейный_доход)** - Уровень дохода семьи (низкий, средний, высокий).
# - **Teacher_Quality (Учитель_Качество)** - Качество преподавателей (низкое, среднее, высокое).
# - **School_Type (Тип_школы)** -	Тип посещаемой школы (государственная, частная).
# - **Peer_Influence** - Влияние сверстников на успеваемость (положительное, нейтральное, отрицательное).
# - **Physical_Activity (Физическая_активность)** -	Среднее количество часов физической активности в неделю.
# - **Learning_Disabilities (Нарушения_обучения)** - Наличие трудностей в обучении (Да, Нет).
# - **Parental_Education_Level (Уровень_родительского_образования)** -	Самый высокий уровень образования родителей (средняя школа, колледж, аспирантура).
# - **Distance_from_Home (Расстояние_от_дома)** - Расстояние от дома до школы (близко, средне, далеко).
# - **Gender (Пол)** - Пол студента (мужчина, женщина).
# - **Exam_Score (Оценка_экзамена)** - Итоговый результат экзамена.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
#  13  Peer_Influence              6607 non-null   object
#  14  Physical_Activity           6607 non-null   int64
#  15  Learning_Disabilities       6607 non-null   object
#  16  Parental_Education_Level    6517 non-null   object
#  17  Distance_from_Home          6540 non-null   object
#  18  Gender                      6607 non-null   object
#  19  Exam_Score                  6607 non-null   int64
# dtypes: int64(7), object(13)
# memory usage: 1.0+ MB

# %%
df.shape
# Out:
# (6607, 20)

# %% [markdown]
# Размерность набора данных: 20 признаков и 6607 наблюдений.
#
# В наборе данных есть пропущенные значения.

# %%
df.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6607.000000  6607.000000   6607.00000      6607.000000
# mean       19.975329    79.977448      7.02906        75.070531
# std         5.990594    11.547475      1.46812        14.399784
# min         1.000000    60.000000      4.00000        50.000000
# 25%        16.000000    70.000000      6.00000        63.000000
# 50%        20.000000    80.000000      7.00000        75.000000
# 75%        24.000000    90.000000      8.00000        88.000000
# max        44.000000   100.000000     10.00000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6607.000000        6607.000000  6607.000000
# mean            1.493719           2.967610    67.235659
# std             1.230570           1.031231     3.890456
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# 50%             1.000000           3.000000    67.000000
# 75%             2.000000           4.000000    69.000000
# max             8.000000           6.000000   101.000000

# %%
df.describe(include=['object']).T
# Out:
#                            count unique          top  freq
# Parental_Involvement        6607      3       Medium  3362
# Access_to_Resources         6607      3       Medium  3319
# Extracurricular_Activities  6607      2          Yes  3938
# Motivation_Level            6607      3       Medium  3351
# Internet_Access             6607      2          Yes  6108
# Family_Income               6607      3          Low  2672
# Teacher_Quality             6529      3       Medium  3925
# School_Type                 6607      2       Public  4598
# Peer_Influence              6607      3     Positive  2638
# Learning_Disabilities       6607      2           No  5912
# Parental_Education_Level    6517      3  High School  3223
# Distance_from_Home          6540      3         Near  3884
# Gender                      6607      2         Male  3814

# %% [markdown]
# ### Вывод
#
# Все значения в пределах нормы, кроме максимального значения Exam_Score

# %% [markdown]
# ### Предобработка данных

# %%
# Проверка на дубликаты
df.duplicated().sum()
# Out:
# 0

# %%
# Проверка на пропущенные значения
df.isna().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64

# %%
df['Teacher_Quality'].value_counts()
# Out:
# Teacher_Quality
# Medium    3925
# High      1947
# Low        657
# Name: count, dtype: int64

# %%
df['Parental_Education_Level'].value_counts()
# Out:
# Parental_Education_Level
# High School     3223
# College         1989
# Postgraduate    1305
# Name: count, dtype: int64

# %%
df['Distance_from_Home'].value_counts()
# Out:
# Distance_from_Home
# Near        3884
# Moderate    1998
# Far          658
# Name: count, dtype: int64

# %%
df['Distance_from_Home'].mode()[0]
# Out:
# 'Near'

# %%
df['Distance_from_Home'] = df['Distance_from_Home'].fillna(value=df['Distance_from_Home'].mode()[0])

# %%
df['Parental_Education_Level'] = df['Parental_Education_Level'].fillna(value=df['Parental_Education_Level'].mode()[0])

# %%
df['Teacher_Quality']=df['Teacher_Quality'].fillna(value=df['Teacher_Quality'].mode()[0])

# %%
df.isna().sum()
# Out:
# Hours_Studied                 0
# Attendance                    0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# Exam_Score                    0
# dtype: int64

# %% [markdown]
# ### Разведочный анализ данных

# %%
df.hist(figsize=(10, 8),  bins=50);

# %%
sns.pairplot(df)

# %% [markdown]
# Есть небольлшая зависимость между Exam_Score и признаками Hours_Studied, Attendance

# %%
map = df[['Hours_Studied', 'Exam_Score', 'Attendance', 'Previous_Scores', 'Physical_Activity', 'Tutoring_Sessions', 'Sleep_Hours']].corr()

# %%
sns.heatmap(df[['Hours_Studied', 'Exam_Score', 'Attendance', 'Previous_Scores', 'Physical_Activity', 'Tutoring_Sessions', 'Sleep_Hours']].corr(), annot=True);
