# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import string
import re
import nltk
import pymorphy3

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df =pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         264 non-null    object
#  1   description   264 non-null    object
#  2   release_date  264 non-null    object
#  3   tags          264 non-null    object
#  4   rating        264 non-null    object
# dtypes: object(5)
# memory usage: 10.4+ KB

# %% [markdown]
# ### Описание набора данных
#
# - title - Название фильма/статьи
# - description - описание
# - release_date - дата выхода
# - tags - ???
# - rating - рейтинг

# %% [markdown]
# ## 2. Предварительная обработка данных

# %%
def remove_punctuation(text): 
    return "".join([ch if ch not in string.punctuation else ' ' for ch in text])

def remove_numbers(text): 
    return ''.join([i if not i.isdigit() else ' ' for i in text])

def remove_multiple_spaces(text): 
    return re.sub(r'\s+', ' ', text, flags=re.I)

st = '❯\xa0—«»'
def remove_othersymbol(text):
    return ''.join([ch if ch not in st else ' ' for ch in text])

# %%
df['prep_text'] = [remove_multiple_spaces(remove_numbers(remove_othersymbol(remove_punctuation(text.lower())))) for text in df['description']]

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating  \
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10
#
#                                            prep_text
# 0   побег из шоушенка фильм который считается одн...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие в готэме его партнера...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  один из присяжных в деле об убийстве пытается ...

# %%
df['description'][0]
# Out:
# '"Побег из Шоушенка" - фильм, который считается одним из лучших в истории кино. Режиссером выступил Фрэнк Дарабонт, а в главных ролях снялись Тим Роббинс и Морган Фриман. Фильм основан на рассказе Стивена Кинга и повествует о бухгалтере Энди Дюфрейне, который осужден за убийство жены и ее любовника. Он отправляется в тюрьму Шоушенк, где сталкивается со многими трудностями и проблемами, но не теряет надежды на свободу. "Побег из Шоушенка" провалился в мировом прокате, был номинирован на несколько премий "Оскар", включая лучший фильм, лучшую режиссуру и лучший сценарий, но не получил ни одной премии. Однако с течением времени фильм "Побег из Шоушенка" стал считаться классикой кинематографа и завоевал множество наград и признаний. В целом, "Побег из Шоушенка" - потрясающий фильм, который оставит незабываемые впечатления у зрителя. Фильм заслуженно стал классикой кинематографа и продолжает радовать зрителей своей глубиной.'

# %%
df['prep_text'][0]
# Out:
# ' побег из шоушенка фильм который считается одним из лучших в истории кино режиссером выступил фрэнк дарабонт а в главных ролях снялись тим роббинс и морган фриман фильм основан на рассказе стивена кинга и повествует о бухгалтере энди дюфрейне который осужден за убийство жены и ее любовника он отправляется в тюрьму шоушенк где сталкивается со многими трудностями и проблемами но не теряет надежды на свободу побег из шоушенка провалился в мировом прокате был номинирован на несколько премий оскар включая лучший фильм лучшую режиссуру и лучший сценарий но не получил ни одной премии однако с течением времени фильм побег из шоушенка стал считаться классикой кинематографа и завоевал множество наград и признаний в целом побег из шоушенка потрясающий фильм который оставит незабываемые впечатления у зрителя фильм заслуженно стал классикой кинематографа и продолжает радовать зрителей своей глубиной '

# %%
russian_stopwords = stopwords.words("russian")

# %%
russian_stopwords.extend(['т.д.', 'т', 'д', 'это','который','с','своём','всем','наш', 'свой'])

# %%
def tokenize(text):
    t = word_tokenize(text)
    tokens = [token for token in t if token not in russian_stopwords]
    text = " ".join(tokens)
    return text

# %%
df['tokenize_text'] = [tokenize(text) for text in df['prep_text']]

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating  \
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10
#
#                                            prep_text  \
# 0   побег из шоушенка фильм который считается одн...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие в готэме его партнера...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  один из присяжных в деле об убийстве пытается ...
#
#                                        tokenize_text
# 0  побег шоушенка фильм считается одним лучших ис...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие готэме партнерами ста...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  присяжных деле убийстве пытается убедить остал...

# %%
stemmer = SnowballStemmer("russian")

stem_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = stemmer.stem(word)
            res.append(p)
        text = " ".join(res)
        stem_list.append(text)
    except Exception as e:
        print(e)
        
df['text_stem'] = stem_list

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating  \
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10
#
#                                            prep_text  \
# 0   побег из шоушенка фильм который считается одн...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие в готэме его партнера...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  один из присяжных в деле об убийстве пытается ...
#
#                                        tokenize_text  \
# 0  побег шоушенка фильм считается одним лучших ис...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие готэме партнерами ста...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  присяжных деле убийстве пытается убедить остал...
#
#                                            text_stem
# 0  побег шоушенк фильм счита одн лучш истор кин р...
# 1  фильм ставш классик сво жанр рассказыва истор ...
# 2  бэтма верш правосуд готэм партнер станов инспе...
# 3  продолжен эпохальн саг режиссер френсис форд к...
# 4  присяжн дел убийств пыта убед остальн присяжн ...

# %%
morph = pymorphy3.MorphAnalyzer(lang='ru')

# %%
# %%time
lemm_texts_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = morph.parse(word)[0]
            res.append(p.normal_form)
        text = " ".join(res)
        lemm_texts_list.append(text)
    except Exception as e:
        print(e)
    
df['text_lemm'] = lemm_texts_list
# Out:
# CPU times: total: 6.27 s
# Wall time: 6.28 s

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating  \
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10
#
#                                            prep_text  \
# 0   побег из шоушенка фильм который считается одн...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие в готэме его партнера...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  один из присяжных в деле об убийстве пытается ...
#
#                                        tokenize_text  \
# 0  побег шоушенка фильм считается одним лучших ис...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие готэме партнерами ста...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  присяжных деле убийстве пытается убедить остал...
#
#                                            text_stem  \
# 0  побег шоушенк фильм счита одн лучш истор кин р...
# 1  фильм ставш классик сво жанр рассказыва истор ...
# 2  бэтма верш правосуд готэм партнер станов инспе...
# 3  продолжен эпохальн саг режиссер френсис форд к...
# 4  присяжн дел убийств пыта убед остальн присяжн ...
#
#                                            text_lemm
# 0  побег шоушенка фильм считаться один хороший ис...
# 1  фильм стать классика свой жанр рассказывать ис...
# 2  бэтман вершить правосудие готэма партнёр стано...
# 3  продолжение эпохальный сага режиссёр френсиса ...
# 4  присяжный дело убийство пытаться убедить остал...

# %%
df['text_lemm'] = [tokenize(text) for text in df['text_lemm']]

# %%
df.head()
# Out:
#                     title                                        description  \
# 0       Побег из Шоушенка  "Побег из Шоушенка" - фильм, который считается...
# 1           Крестный отец  Фильм, ставший классикой своего жанра, рассказ...
# 2           Темный рыцарь  Бэтман вершит правосудие в Готэме. Его партнер...
# 3         Крестный отец 2  Продолжение эпохальной саги режиссера Френсиса...
# 4  12 разгневанных мужчин  Один из 12 присяжных  в деле об убийстве пытае...
#
#   release_date                                          tags   rating  \
# 0   06.01.1995                                         драма  9.44/10
# 1   24.03.1972                                драма, триллер  9.11/10
# 2   12.08.2008  боевик, драма, кинокомикс, криминал, триллер  9.12/10
# 3   12.12.1974                               драма, криминал  8.88/10
# 4   29.07.1957                               детектив, драма  9.15/10
#
#                                            prep_text  \
# 0   побег из шоушенка фильм который считается одн...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие в готэме его партнера...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  один из присяжных в деле об убийстве пытается ...
#
#                                        tokenize_text  \
# 0  побег шоушенка фильм считается одним лучших ис...
# 1  фильм ставший классикой своего жанра рассказыв...
# 2  бэтман вершит правосудие готэме партнерами ста...
# 3  продолжение эпохальной саги режиссера френсиса...
# 4  присяжных деле убийстве пытается убедить остал...
#
#                                            text_stem  \
# 0  побег шоушенк фильм счита одн лучш истор кин р...
# 1  фильм ставш классик сво жанр рассказыва истор ...
# 2  бэтма верш правосуд готэм партнер станов инспе...
# 3  продолжен эпохальн саг режиссер френсис форд к...
# 4  присяжн дел убийств пыта убед остальн присяжн ...
#
#                                            text_lemm
# 0  побег шоушенка фильм считаться хороший история...
# 1  фильм стать классика жанр рассказывать история...
# 2  бэтман вершить правосудие готэма партнёр стано...
# 3  продолжение эпохальный сага режиссёр френсиса ...
# 4  присяжный дело убийство пытаться убедить остал...

# %% [markdown]
# ### Облако слов

# %%
# Получение текстовой строки из списка слов
def str_corpus(corpus):
    str_corpus = ''
    for i in corpus:
        str_corpus += ' ' + i
    str_corpus = str_corpus.strip()
    return str_corpus

# Получение списка всех слов в корпусе
def get_corpus(data):
    corpus = []
    for phrase in data:
        for word in phrase.split():
            corpus.append(word)
    return corpus

# Получение облака слов
def get_wordCloud(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(str_corpus(corpus))
    return wordCloud

# %%
corpus = get_corpus(df['description'].values)
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
# Получение облака слов
def get_wordCloud2(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(corpus)
    return wordCloud

# %%
corpus = df['text_lemm'][0]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
corpus = df['text_lemm'][1]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
df['text_lemm'][1]
# Out:
# 'фильм стать классика жанр рассказывать история влиятельный нью йоркский мафиозный клан корлеон'

# %%
corpus = df['text_lemm'][2]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
df['text_lemm'][2]
# Out:
# 'бэтман вершить правосудие готэма партнёр становиться инспектор полиция гордон новый окружный прокурор харви дента трио готовый искоренить преступность город однако появление новый безжалостный преступник кличка джокер свести усилие'

# %% [markdown]
# ## Векторизация текстовых данных

# %%
df['text_lemm'][0]
# Out:
# 'побег шоушенка фильм считаться хороший история кино режиссёр выступить фрэнк дарабонт главный роль сняться тим роббинс морган фриман фильм основать рассказ стивен кинг повествовать бухгалтер энди дюфрейн осудить убийство жена любовник отправляться тюрьма шоушенк сталкиваться многий трудность проблема терять надежда свобода побег шоушенка провалиться мировой прокат номинировать несколько премия оскар включая хороший фильм хороший режиссура хороший сценарий получить премия однако течение время фильм побег шоушенка стать считаться классика кинематограф завоевать множество награда признание целое побег шоушенка потрясать фильм оставить незабываемый впечатление зритель фильм заслуженно стать классика кинематограф продолжать радовать зритель глубина'

# %%
vectorizer = CountVectorizer()
vectorizer.fit(df['text_lemm'])
# Out:
# CountVectorizer()

# %%
print(vectorizer.vocabulary_)
# Out:
# {'побег': 3965, 'шоушенка': 6277, 'фильм': 6011, 'считаться': 5572, 'хороший': 6129, 'история': 2412, 'кино': 2507, 'режиссёр': 4896, 'выступить': 1548, 'фрэнк': 6065, 'дарабонт': 1734, 'главный': 1620, 'роль': 4977, 'сняться': 5267, 'тим': 5674, 'роббинс': 4958, 'морган': 3073, 'фриман': 6061, 'основать': 3668, 'рассказ': 4843, 'стивен': 5478, 'кинг': 2503, 'повествовать': 3987, 'бухгалтер': 1163, 'энди': 6338, 'дюфрейн': 1983, 'осудить': 3689, 'убийство': 5795, 'жена': 2022, 'любовник': 2857, 'отправляться': 3755, 'тюрьма': 5779, 'шоушенк': 6276, 'сталкиваться': 5447, 'многий': 3032, 'трудность': 5749, 'проблема': 4523, 'терять': 5652, 'надежда': 3141, 'свобода': 5064, 'провалиться': 4528, 'мировой': 3019, 'прокат': 4593, 'номинировать': 3411, 'несколько': 3363, 'премия': 4385, 'оскар': 3661, 'включая': 1305, 'режиссура': 4895, 'сценарий': 5566, 'получить': 4160, 'однако': 3550, 'течение': 5669, 'время': 1431, 'стать': 5467, 'классика': 2526, 'кинематограф': 2504, 'завоевать': 2062, 'множество': 3042, 'награда': 3139, 'признание': 4442, 'целое': 6158, 'потрясать': 4278, 'оставить': 3680, 'незабываемый': 3292, 'впечатление': 1417, 'зритель': 2237, 'заслуженно': 2172, 'продолжать': 4561, 'радовать': 4725, 'глубина': 1626, 'жанр': 2012, 'рассказывать': 4845, 'влиятельный': 1315, 'нью': 3435, 'йоркский': 2436, 'мафиозный': 2942, 'клан': 2522, 'корлеон': 2655, 'бэтман': 1178, 'вершить': 1240, 'правосудие': 4315, 'готэма': 1675, 'партнёр': 3839, 'становиться': 5451, 'инспектор': 2334, 'полиция': 4143, 'гордон': 1653, 'новый': 3408, 'окружный': 3587, 'прокурор': 4599, 'харви': 6089, 'дента': 1790, 'трио': 5738, 'готовый': 1674, 'искоренить': 2377, 'преступность': 4400, 'город': 1662, 'появление': 4302, 'безжалостный': 1011, 'преступник': 4399, 'кличка': 2538, 'джокер': 1840, 'свести': 5058, 'усилие': 5922, 'продолжение': 4563, 'эпохальный': 6343, 'сага': 5016, 'френсиса': 6059, 'форд': 6039, 'копполый': 2650, 'развитие': 4740, 'мафия': 2943, 'америка': 892, 'поколение': 4123, 'гангстер': 1579, 'отец': 3715, 'дон': 1921, 'сын': 5582, 'превращать': 4327, 'построить': 4253, 'старый': 5462, 'сицилицийский': 5158, 'закон': 2104, 'жестсковать': 2029, 'жестокий': 2027, 'структура': 5520, 'внедриться': 1328, 'большой': 1112, 'бизнес': 1060, 'присяжный': 4501, 'дело': 1783, 'пытаться': 4703, 'убедить': 5791, 'остальной': 3682, 'предстоять': 4369, 'вынести': 1513, 'решение': 4936, 'просто': 4626, 'казаться': 2444, 'первый': 3854, 'взгляд': 1265, 'немецкий': 3316, 'фабрикант': 5977, 'член': 6227, 'нацистский': 3246, 'партия': 3838, 'шиндлера': 6263, 'использовать': 2392, 'труд': 5746, 'еврей': 1986, 'фабрика': 5976, 'польша': 4167, 'второй': 1470, 'война': 1372, 'остаться': 3685, 'безучастный': 1021, 'ужас': 5841, 'творить': 5610, 'нацист': 3245, 'спасти': 5377, 'тысяча': 5775, 'участь': 5961, 'умертвщленный': 5879, 'газовый': 1572, 'камера': 2455, 'концентрационный': 2642, 'лагер': 2760, 'освенцим': 3655, 'близиться': 1080, 'последний': 4226, 'битва': 1073, 'средиземье': 5428, 'путь': 4697, 'войско': 1373, 'саурон': 5039, 'стоить': 5483, 'лишь': 2826, 'королевство': 2660, 'гондора': 1649, 'управлять': 5907, 'выжить': 1497, 'ум': 5874, 'наместник': 3180, 'денетор': 1788, 'сила': 5134, 'хранитель': 6141, 'кольцо': 2570, 'иссякать': 2407, 'мера': 2972, 'продвижение': 4555, 'мордору': 3075, 'мир': 3017, 'поверженный': 3978, 'тьма': 5776, 'жизнь': 2035, 'бандит': 987, 'винсент': 1296, 'вега': 1206, 'джулс': 1847, 'винфилд': 1298, 'работать': 4712, 'марселлас': 2916, 'уоллес': 5899, 'преступный': 4401, 'босс': 1123, 'лос': 2847, 'анджелес': 916, 'поиск': 4108, 'великий': 1218, 'завершить': 2054, 'оно': 3592, 'попасть': 4196, 'рука': 4993, 'хоббит': 6116, 'шир': 6264, 'решимость': 4937, 'стойкость': 5484, 'зависеть': 2057, 'судьба': 5534, 'фродый': 6063, 'бэгинс': 1172, 'глава': 1617, 'братство': 1130, 'мордора': 3074, 'дабы': 1714, 'уничтожить': 5896, 'горнило': 1659, 'роковой': 4976, 'гора': 1651, 'действие': 1770, 'происходить': 4589, 'разгар':  ...

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words=russian_stopwords, ngram_range=(1, 3), min_df=2)
count_matrix = vectorizer.fit_transform(df['text_lemm'])

# %%
count_matrix.shape
# Out:
# (264, 9216)

# %%
vectorizer.get_feature_names_out()[7000:8000]
# Out:
# array(['разношёрстный парк старый', 'разный', 'разный человек',
#        'разобрать', 'разобраться', 'разобраться вопрос',
#        'разобраться вопрос предлагать', 'разом', 'разраб',
#        'разрабатывать', 'разработать', 'разработать прототип',
#        'разработать прототип улучшать', 'разработка', 'разработка linux',
#        'разработка linux разработка', 'разработка raspberry',
#        'разработка raspberry pi', 'разработка администрирование',
#        'разработка администрирование дизайн', 'разработка прототип',
#        'разработка прототип запускать', 'разработка эмулятор',
#        'разработка эмулятор решение', 'разработчик', 'разработчик bluez',
#        'разработчик bluez рекомендовать', 'разработчик создавать',
#        'разрушить', 'разрушить злой', 'разум', 'разумеется',
#        'разумеется использовать', 'разумеется использовать информация',
#        'разъём', 'разъём raspberry', 'разъём raspberry pi',
#        'разъём возможный', 'разъём возможный установка',
#        'разъём компьютер', 'разъём компьютер подождать',
#        'разъём подключение', 'разъём подключение например', 'рамка',
#        'ранний', 'раскрывать', 'раскрывать секрет',
#        'раскрывать секрет загрузочный', 'раскрыть', 'распайка',
#        'распайка кабель', 'распайка кабель otg', 'расписать',
#        'расписать документация', 'расписать документация утилит',
#        'распознаваться', 'распознаваться внешний',
#        'распознаваться внешний usb', 'распознаваться компьютер',
#        'распознаваться компьютер внешний', 'распознаваться несколько',
#        'распознаваться несколько устройство', 'распределённый',
#        'распределённый система', 'распространение', 'распространить',
#        'распространить стек', 'распространить стек bluez', 'рассказ',
#        'рассказать', 'рассказать ещё', 'рассказать ещё способ',
#        'рассказать обычно', 'рассказать обычно работать',
#        'рассказать протокол', 'рассказать протокол предстоять',
#        'рассказывать', 'рассказывать история', 'рассказывать реальный',
#        'рассказывать реальный история', 'расследование',
#        'расследование дело', 'расследовать', 'расследовать дело',
#        'рассмотреть', 'рассмотреть вариант', 'расставаться', 'расстаться',
#        'расти', 'расширить', 'реализация', 'реализация init',
#        'реализация init данный', 'реализация должный',
#        'реализация должный понятный', 'реализация называть',
#        'реализация называть systemd', 'реализация операционный',
#        'реализация операционный система', 'реализация пользоваться',
#        'реализация пользоваться эмулятор', 'реализация привести',
#        'реализация привести выше', 'реализация протокол',
#        'реализация протокол описать', 'реализация следующий',
#        'реализация следующий общение', 'реализация создать',
#        'реализация создать проект', 'реализация требовать',
#        'реализация требовать никакой', 'реализовать',
#        'реализовать raspberry', 'реализовать raspberry pi',
#        'реализовать использование', 'реализовать использование паяльник',
#        'реализовать различный', 'реализовать различный одноплатный',
#        'реализоваться', 'реализоваться абстракция',
#        'реализоваться абстракция специальный', 'реально',
#        'реально ассоциировать', 'реально ассоциировать файл',
#        'реально использоваться', 'реально использоваться эмуляция',
#        'реально сделать', 'реально сделать видеть', 'реальность',
#        'реальный', 'реальный история', 'реальный событие',
#        'реальный событие произойти', 'ребёнок', 'ребёнок жизнь',
#        'регистрация', 'регистрация август', 'регистрация август дата',
#        'регистрация июль', 'регистрация июль дата', 'регистрация март',
#        'регистрация март дата', 'регистрация публикация',
#        'регистрация публикация новость', 'регистрация раздел',
#        'регистрация раздел публикация', 'регистрация раздел статья',
#        'регистрироваться', 'регистрироваться ник',
#        'регистрироваться ник ставить', 'редакторский',
#        'редакторский дайджест', 'редакторский дайджест присылать',
#        'режим', 'режим device', 'режим device otg',
#        'режим device существовать', 'режим hdd', 'режим hdd запись',
#        'режим host', 'режим host device', 'режим host должный',
#        'режим аппаратный', 'режим аппаратный помощь', 'режим начало',
#        'режим начало сразу', 'режим особенность',
#        'режим особенность эмулятор', 'режим периферийный',
#        'режим периферийный устройство', 'режим подключение',
#        'режим подключение wi', 'режим работа', 'режим работа raspberry',
#        'режим работать', 'режим работать raspberry', 'режим режим',
#        'режим режим работать', 'режим совместимость',
#        'режим совместимость логика', 'режим хост', 'режим хост host',
#        'режим хост подразумевать', 'режим хост программный',
#        'режим хост режим', 'режим экономия', 'режим экономия энергия',
#        'режим эмуляция', 'режим эмуляция внешний', 'режиссура',
#        'режиссура хороший', 'режиссура хороший сценарий', 'режиссёр',
#        'результат', 'результат вдохновлять',
#        'результат вдохновлять больший', 'результат запуск',
#        'результат запуск команда', 'результат некоторый',
#        'результат некоторый учётный', 'результат решить',
#        'результат решить поделиться', 'резюме', 'рейтинг',
#        'рейтинг cloud', 'рейтинг cloud cloud',
#        'рейтинг cloud корпоративный', 'рейтинг пользователь',
#        'рейтинг пользователь комментарий', 'рейх', 'реклама',
#        'реклама комментарий', 'реклама нативный',
#        'реклама нативный проект', 'реклама читать', 'рекомендовать',
#        'рекомендовать использовать', 'рекомендовать использовать новый',
#        'релевантный', 'религиозный', 'релиз', 'реликвия', 'репозиторий',
#        'репозиторий git', 'репозиторий github',
#        'репозиторий github написание', 'ресторан', 'ресурс', 'ретроигра',
#        'ретроигра тег', 'ретроигра тег linux', 'речь', 'речь идти',
#        'решать', 'решать найти', 'решать помочь', 'решать проблема',
#        'решать проблема перезагрузка', 'решаться', 'решение',
#        'решение должный', 'решение должный небольшой', 'решение задача',
#        'решение задача лаконично', 'решение заключаться',
#        'решение заключаться модифицировать', 'решение небольшой',
#        'решение небольшой модификация', 'решение обладать',
#        'решение обладать рядом', 'решение определённый',
#        'решение определённый задача', 'решение практика',
#        'решение практика делать', 'решение практика проверка',
#        'решение применять', 'решение применять проверять',
#        'решение проверка', 'решение проверка решение', 'решение решение',
#        'решение решение заключаться', 'решение смочь',
#        'решение смочь повторить', 'решение установить',
#        'решение установить операционный', 'решение являться',
#        'решение являться прототип', 'решимость', 'решить',
#        'решить поделиться', 'решить поделиться узнать', 'ринг', 'риск',
#        'риф', 'роберт', 'робот', 'род', 'родитель', 'родный',
#        'родный город', 'розыгрыш', 'розыгрыш приз',
#        'розыгрыш приз новость', 'роль', 'роль периферийный',
#        'роль периферийный устройство', 'роль хост', 'роман', 'роскошный',
#        'российский', 'россия', 'россия представитель',
#        'россия представитель ruvds', 'рубль', 'рука', 'руководитель',
#        'руководить', 'руководство', 'русский', 'рутина', 'ручной',
#        'ручной тестирование', 'рф', 'рф спасибо', 'рф спасибо внимание',
#        'рынок', 'рынок труд', 'рыцарь', 'ряд', 'рядовой',
#        'рядовой отказаться', 'рядом', 'рядом недостаток',
#        'рядом недостаток сравнение', 'рядом устроенный',
#        'рядом устроенный буфер', 'сайт', 'сайт facebook',
#        'сайт facebook twitter', 'сайт microsoft',
#        'сайт microsoft создание', 'сайт raspberrypi',
#        'сайт raspberrypi org', 'сайт ruvds', 'сайт ruvds com', 'сайт www',
#        'сайт www cloud', 'сайт автор', 'сайт автор компания',
#        'сайт вконтакте', 'сайт вконтакте telegram', 'сайт сайт',
#        'самостоятельно', 'самостоятельно изучить',
#        'самостоятельно изучить углублённый', 'самостоятельный',
#        'самоубийство', 'самоучитель', 'самоучитель работа',
#        'самоучитель работа raspberry', 'самурай', 'самый',
#        'самый весёлый', 'самый интересный', 'самый интересный клавиатура',
#        'самый популярный', 'самый распространить', 'самый страшный',
#        'сара', 'сара коннора', 'саурон', 'сбегать', 'сбежать', 'сбер',
#        'сбор', 'сборка', 'сборка модификация',
#        'сборка модификация дистрибутив', 'свадьба', 'сверхспособность',
#        'свести', 'свет', 'свидетель', 'свобода', 'свободный', 'связанный',
#        'связать', 'связывать', 'связывать устройство',
#        'связывать устройство проводы', 'связь', 'святой', 'священник',
#        'священный', 'сдаваться', 'сделать', 'сделать видеть',
#        'сделать видеть положительный', 'сделать компьютер',
#        'сделать компьютер ваш', 'сделать необходимый',
#        'сделать необходимый настройка', 'сделать нужный',
#        'сделать нужный дополнительный', 'сделать обычный',
#        'сделать обычный компьютер', 'сделать одноплатник',
#        'сделать одноплатник аппаратный', 'сделать полноценный',
#        'сделать полноценный аппаратный', 'сделать помощь',
#        'сделать помощь docker', 'сделать помощь приложение',
#        'сделать следующий', 'сделать следующий команда',
#        'сделать сопряжение', 'сделать сопряжение bluetooth',
#        'сделать управление', 'сделать управление телефон',
#        'сделать устройство', 'сделать устройство видимый',
#        'сделать устройство похожий', 'сделать хороший', 'север',
#        'сегодня', 'сей', 'сей пора', 'сей пора убрать', 'секрет',
#        'секрет загрузочный', 'секрет загрузочный iso', 'селина',
#        'семейный', 'семеро', 'семь', 'семья', 'сервер',
#        'сервер выделяться', 'сервер выделяться канал', 'сервис',
#        'сервис находиться', 'сервис находиться хост', 'сервис устройство',
#        'сердце', 'середина', 'серийный', 'серийный убийца', 'серия',
#        'серьёзный', 'сестра', 'сетевой', 'сетевой карта',
#        'сетевой карта ssh', 'сетевой карта загрузить',
#        'сетевой карта флэш', 'сеть', 'сеть найти', 'сеть найти ip',
#        'сеть подключиться', 'сеть подключиться протокол',
#        'сеть сообщество', 'сидеть', 'сила', 'сила пытаться', 'сильно',
#        'сильный', 'символ', 'симптом', 'система', 'система bluetooth',
#        'система bluetooth контроллер', 'система configfs',
#        'система configfs директория', 'система exfat',
#        'система exfat блочный', 'система iso', 'система iso образ',
#        'система linux', 'система linux usb', 'система linux аппаратный',
#        'система linux одноплатный', 'система linux ядро',
#        'система raspberry', 'система raspberry pi', 'система sd',
#        'система sd карта', 'система soc', 'система soc факт',
#        'система ассоциировать', 'система ассоциировать раздел',
#        'система блочный', 'система блочный устройство', 'система её',
#        'система её позаимствовать', 'система затем', 'система затем ядро',
#        'система иметь', 'система иметь usb', 'система использоваться',
#        'система использоваться команда', 'система казаться',
#        'система казаться немного', 'система компьютер',
#        'система компьютер поэтому', 'система корневой',
#        'система корневой файловый', 'система корректно',
#        'система корректно загрузить', 'система корректный',
#        'система корректный выбор', 'система многие',
#        'система многие деталь', 'система осуществляться',
#        'система осуществляться работа', 'система получить',
#        'система получить устройство', 'система помощь',
#        'система помощь команда', 'система понадобиться',
#        'система понадобиться ещё', 'система поставляться',
#        'система поставляться вид', 'система превратить',
#        'система превратить ещё', 'система разместить',
#        'система разместить блочный', 'система сказать',
#        'система сказать zphisher', 'система создать',
#        'система создать эмулятор', 'система широкий',
#        'система широкий спектр', 'система являться',
#        'система являться директория', 'систематизировать',
#        'систематизировать знание', 'систематизировать знание поэтому',
#        'системный', 'системный администрирование',
#        'системный администрирование разработка', 'сити', 'ситуация',
#        'сказать', 'сказать zphisher', 'сказать zphisher установить',
#        'сказать программирование', 'сказать программирование скучно',
#        'сказать существовать', 'сказать существовать ещё', 'сказочный',
#        'скайнуть', 'скайуокер', 'скандал', 'скачать', 'скачать образ',
#        'скачать образ raspberry', 'сколько', 'сколько человек',
#        'сконфигурировать', 'сконфигурировать service',
#        'сконфигурировать service discovery',
#        'сконфигурировать устройство',
#        'сконфигурировать устройство помощь', 'скорее',
#        'скорее встречаться', 'скорее встречаться например',
#        'скорее ограничение', 'скорее ограничение ядро', 'скоро',
#        'скорость', 'скорость запись', 'скорость запись пользователь',
#        'скорый', 'скрипт', 'скрипт co', 'скрипт co вспомогательный',
#        'скрипт выполняться', 'скрипт выполняться docker',
#        'скрипт запускаться', 'скрипт запускаться служба',
#        'скрипт обработка', 'скрипт обработка команда',
#        'скрипт оформляться', 'скрипт оформляться вид', 'скрипт первый',
#        'скрипт первый загрузка', 'скрываться', 'скрываться думать',
#        'скрываться думать контроллер', 'скрытый', 'скучно', 'скучно мина',
#        'скучно мина tutelka', 'слева', 'след', 'следить', 'следовать',
#        'следующий', 'следующий вид', 'следующий вид usb',
#        'следующий загрузка', 'следующий загрузка linux',
#        'следующий качество', 'следующий качество параметр',
#        'следующий команда', 'следующий общение',
#        'следующий общение raspberry', 'следующий файл',
#        'следующий файл dockerfile', 'следующий цель',
#        'следующий цель аппаратный', 'следующий шаг',
#        'следующий шаг полностью', 'слишком', 'слово', 'сложность',
#        'сложность заключаться', 'сложность заключаться работать',
#        'сложный', 'сложный задача', 'сложный задача блочный',
#        'сложный микросхема', 'сложный микросхема позволять', 'служба',
#        'служба journalctl', 'служба journalctl sn', 'служба serial',
#        'служба serial getty', 'служба systemctl',
#        'служба systemctl enable', 'служба systemctl status',
#        'служба systemctl stop', 'служба systemd',
#        'служба systemd firstboot', 'служба systemd запуск',
#        'служба systemd инициализация', 'служба systemd управление',
#        'служба автоматически', 'служба автоматически запустить',
#        'служба запускать', 'служба запускать интерпретатор',
#        'служба запускать эмулятор', 'служба зарегистрировать',
#        'служба зарегистрировать хост', 'служба начинать',
#        'служба начинать момент', 'служба представлять',
#        'служба представлять эмуляция', 'служба служба',
#        'служба служба автоматически', 'служебный', 'служебный лестница',
#        'служить', 'слух', 'случай', 'случай bluetooth',
#        'случай bluetooth контроллер', 'случай ssh',
#        'случай ssh соединение', 'случай использовать',
#        'случай использовать визуальный', 'случай операционный',
#        'случай операционный система', 'случай последовательный',
#        'случай последовательный порт', 'случай предпочтительный',
#        'случай предпочтительный второй', 'случай создать',
#        'случай создать композитный', 'случай эмуляция',
#        'случай эмуляция cd', 'случайно', 'случайный', 'случиться',
#        'слушать', 'слушать определённый', 'слушать определённый канал',
#        'смертельный', 'смерть', 'смешанный', 'смешной', 'смотреть',
#        'смочь', 'смочь повторить', 'смочь повторить одноплатный', 'смысл',
#        'смысл рассказать', 'смысл рассказать обычно', 'сначала',
#        'сначала загружаться', 'сначала загружаться ядро', 'снижение',
#        'снизить', 'снизить скорость', 'снизить скорость запись', 'снова',
#        'снова запустить', 'снова запустить zphisher', 'снятие',
#        'снятие iso', 'снятие iso образ', 'снятой', 'снятой мотив',
#        'снять', 'сняться', 'собирать', 'собирать docker',
#        'собирать docker образ', 'собирать образ',
#        'собирать образ raspberrypi', 'собираться', 'собранный', 'собрать',
#        'собраться', 'собственный', 'собственный жизнь',
#        'собственный сервер', 'событие', 'событие история',
#        'событие произойти', 'совершать', 'совершенно',
#        'совершенно бесплатный', 'совершенно бесплатный посмотреть',
#        'совершенно разный', 'совершенный', 'совершить', 'совет',
#        'совместимость', 'совместимость логика',
#        'совместимость логика написать', 'совместно', 'современный',
#        'согласиться', 'соглашаться', 'соглашаться pin',
#        'соглашаться pin код', 'соглашение',
#        'соглашение конфиденциальность',
#        'соглашение конфиденциальность корпоративный',
#        'соглашение конфиденциальность услуга', 'содержание',
#        'содержание реализация', 'содержание реализация следующий',
#        'содержать', 'содержать абстракция', 'содержать абстракция работа',
#        'содержать информация', 'содержать информация необходимо',
#        'содержать модуль', 'содержать модуль позволять',
#        'содержать никакой', 'содержать никакой данные',
#        'содержать подключение', 'содержать подключение overlay',
#        'содержать реально', 'содержать реально использоваться',
#        'содержать файл', 'содержать файл readme', 'соединение',
#        'соединение agetty', 'соединение agetty случай',
#        'соединение bluetooth', 'соединение bluetooth поддержка',
#        'соединение ethernet', 'соединение ethernet wi',
#        'соединение raspberry', 'соединение raspberry pi',
#        'соединение запускать', 'соединение запускать процесс',
#        'соединение последовательный', 'соединение последовательный порт',
#        'соединение телефон', 'соединение телефон raspberry', 'соединить',
#        'сожаление', 'создавать', 'создавать rfcomm',
#        'создавать rfcomm соединение', 'создавать блочный',
#        'создавать блочный устройство', 'создавать виртуальный',
#        'создавать виртуальный usb', 'создавать виртуальный соединение',
#        'создавать конфигурация', 'создавать новый', 'создавать образ',
#        'создавать образ раздел', 'создавать подключать',
#        'создавать подключать функция', 'создавать соединение',
#        'создавать соединение последовательный', 'создаваться',
#        'создаваться сервер', 'создаваться сервер выделяться', 'создание',
#        'создание usb', 'создание usb устройство', 'создание композитный',
#        'создание композитный usb', 'создание пайплайна',
#        'создание процесс', 'создание процесс слушать',
#        'создание структура', 'создание структура файловый',
#        'создание файловый', 'создание файловый система', 'создатель',
#        'создать', 'создать аппаратный', 'создать аппаратный эмулятор',
#        'создать год', 'создать год назад', 'создать композитный',
#        'создать композитный usb', 'создать минималистичный',
#        'создать минималистичный дистрибутив', 'создать несколько',
#        'создать несколько подключение', 'создать новый',
#        'создать подключение', 'создать подключение raspberry',
#        'создать полезный', 'создать полезный нагрузка', 'создать проект',
#        'создать проект состоять', 'создать удобный',
#        'создать удобный графический', 'создать устройство',
#        'создать фишинговый', 'создать фишинговый ссылка',
#        'создать эмулятор', 'создать эмулятор cd', 'сократить',
#        'сократить время', 'сократить время компиляция', 'солдат', 'соло',
#        'сон', 'сообщать', 'сообщение', 'сообщество', 'сообщить',
#        'соответствие', 'соответствие спецификация',
#        'соответствие спецификация bluetooth', 'сопротивление',
#        'сопрягать', 'сопрягать устройство', 'сопрягать устройство её',
#        'сопряжение', 'сопряжение bluetooth',
#        'сопряжение bluetooth raspberry', 'сопряжение usb',
#        'сопряжение usb компьютер', 'сопряжение usb периферийный',
#        'сопряжение подробно', 'сопряжение подробно расписать',
#        'сопряжение телефон', 'сопряжение телефон raspberry', 'сосед',
#        'сосредоточить', 'сосредоточиться', 'сосредоточиться нельзяграм',
#        'сосредоточиться нельзяграм итак', 'составить', 'составной',
#        'составной устройство', 'составной устройство помочь', 'состояние',
#        'состоятельный', 'состоять', 'состоять следующий',
#        'состоять следующий файл', 'состоять часть',
#        'состоять часть часть', 'сотня', 'сотрудник', 'сотрудничать',
#        'софт', 'социальный', 'социальный сеть',
#        'социальный сеть сообщество', 'соцсеть', 'соцсеть osint',
#        'соцсеть osint хаба', 'соцсеть нехороший',
#        'соцсеть нехороший ввод', 'соцсеть цель', 'соцсеть цель узнать',
#        'соцсеть являться', 'соцсеть являться уголовный', 'союзник',
#        'спасательный', 'спасательный капсула', 'спасать', 'спасибо',
#        'спасибо внимание', 'спаситель', 'спасти', 'спасти тысяча',
#        'спектр', 'спектр компьютер', 'спектр компьютер путём',
#        'специалист', 'специально', 'специальность', 'специальный',
#        'специальный программа', 'специальный программа взаимодействовать',
#        'специальный программа называть', 'спецификация',
#        'спецификация bluetooth', 'спецификация bluetooth bluetooth',
#        'спецификация bluetooth освещать',
#        'спецификация bluetooth протокол',
#        'спецификация bluetooth спецификация', 'спецпроект', 'список',
#        'список доступный', 'список доступный iso',
#        'список доступный команда', 'спорить', 'спорт', 'способ',
#        'способ заинтересовать', 'способ заинтересовать проверить',
#        'способ модуль', 'способ модуль динамически', 'способ оказываться',
#        'способ оказываться вшить', 'способ эмулировать',
#        'способ эмулировать оптический', 'способность', 'способный',
#        'справа', 'справедливость', 'справиться', 'справляться', 'спустя',
#        'спустя год', 'сравнение', 'сравнение карман',
#        'сравнение карман zalman', 'сравнить', 'сражаться', 'сражение',
#        'сразу', 'сразу запись', 'сразу запись образ', 'среда', 'среди',
#        'средиземье', 'среднее', 'средний', 'средний мина', 'средство',
#        'средство linux', 'средство linux практически', 'срок', 'срочно',
#        'ссылаться', 'ссылаться статья', 'ссылаться статья признать',
#        'ссылка', 'ссылка доверять', 'ссылка доверять разумеется',
#        'ссылка нажатие', 'ссылка нажатие открываться', 'ссылка начать',
#        'ссылка начать получать', 'ссылка отправить',
#        'ссылка отправить жертва', 'ссылка создать',
#        'ссылка создать полезный', 'ставить', 'ставить slash',
#        'ставить zphisher', 'ставить zphisher github', 'ставка', 'стадия',
#        'сталкиваться', 'стандарт', 'становиться', 'стараться', 'стартап',
#        'стартап мегапроект', 'стартап мегапроект информация',
#        'стартап мегапроект настройка', 'стартап настройка',
#        'стартап настройка язык', 'старшеклассник', 'старший',
#        'старший брат', 'старый', 'старый версия', 'старый версия habr',
#        'старый персональный', 'старый персональный компьютер',
#        'старый устаревший', 'старый устаревший приложение', 'статистика',
#        'статический', 'статус', 'статус служба',
#        'статус служба systemctl', 'стать', 'стать внешний',
#        'стать внешний usb', 'стать классика', 'стать первый',
#        'стать программа', 'стать программа drivedroid', 'стать простой',
#        'стать прототип', 'стать самый', 'стать участник', 'статья',
#        'статья лишь', 'статья лишь поверхностно'], dtype=object)

# %%
print(count_matrix)
# Out:
#   (0, 5743)	4
#   (0, 8763)	6
#   (0, 8140)	2
#   (0, 8850)	4
#   (0, 3728)	1
#   (0, 3870)	1
#   (0, 7192)	1
#   (0, 2569)	1
#   (0, 8814)	1
#   (0, 2604)	1
#   (0, 7283)	1
#   (0, 7684)	1
#   (0, 5399)	1
#   (0, 7068)	1
#   (0, 8043)	1
#   (0, 3868)	1
#   (0, 9151)	1
#   (0, 5433)	1
#   (0, 8314)	1
#   (0, 3095)	1
#   (0, 4283)	1
#   (0, 5520)	1
#   (0, 8309)	1
#   (0, 7961)	1
#   (0, 4444)	1
#   :	:
#   (263, 3586)	2
#   (263, 3182)	1
#   (263, 1263)	3
#   (263, 371)	2
#   (263, 4570)	1
#   (263, 7085)	1
#   (263, 2315)	1
#   (263, 4658)	1
#   (263, 5974)	1
#   (263, 3183)	1
#   (263, 6299)	1
#   (263, 374)	3
#   (263, 1264)	1
#   (263, 8098)	1
#   (263, 6300)	1
#   (263, 3736)	1
#   (263, 6849)	1
#   (263, 375)	1
#   (263, 6478)	1
#   (263, 8244)	1
#   (263, 4833)	1
#   (263, 2271)	1
#   (263, 7441)	1
#   (263, 2441)	1
#   (263, 6853)	1

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000,
                                 min_df=0.01, stop_words=russian_stopwords,
                                 ngram_range=(1,3))

# %%
# %%time
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text_lemm'])
# Out:
# CPU times: total: 297 ms
# Wall time: 320 ms

# %%
tfidf_matrix.shape
# Out:
# (264, 1781)

# %%
tfidf_vectorizer.get_feature_names_out()[:100]
# Out:
# array(['add', 'ai', 'android', 'api', 'apple', 'arm', 'bin', 'build',
#        'cd', 'chatgpt', 'class', 'cloud', 'com', 'com дата',
#        'com дата регистрация', 'communications', 'config', 'data', 'dev',
#        'docker', 'facebook', 'facebook twitter',
#        'facebook twitter вконтакте', 'fat', 'foundation', 'gen', 'git',
#        'github', 'github com', 'google', 'habr', 'help', 'host', 'https',
#        'https github', 'https github com', 'image', 'instagram',
#        'install', 'ios', 'ip', 'ip адрес', 'it', 'it пост',
#        'it пост ретроигра', 'js', 'json', 'lib', 'linux', 'list', 'local',
#        'local bin', 'mac', 'manager', 'meta', 'microsoft', 'modules',
#        'name', 'new', 'node', 'org', 'os', 'pcie', 'port', 'python',
#        'readme', 'ru', 'ru дата', 'ru дата регистрация', 'run', 'ruvds',
#        'ruvds com', 'ruvds com дата', 'sap', 'sh', 'source', 'sql', 'ssh',
#        'start', 'status', 'system', 'tech', 'telegram',
#        'telegram вконтакте', 'telegram вконтакте twitter',
#        'telegram канал', 'telegram канал розыгрыш',
#        'telegram комментарий', 'telegram комментарий публикация', 'the',
#        'tree', 'twitter', 'twitter вконтакте', 'twitter карма',
#        'twitter карма рейтинг', 'txt', 'url', 'usr', 'usr local',
#        'usr local bin'], dtype=object)

# %%
print(tfidf_matrix)
# Out:
#   (0, 1679)	0.3857497710041307
#   (0, 1556)	0.2080527242538306
#   (0, 1704)	0.2899080618323248
#   (0, 556)	0.06021246463336326
#   (0, 592)	0.10999174590646044
#   (0, 1324)	0.09926309517114014
#   (0, 1692)	0.11365077961708983
#   (0, 321)	0.09036909636299677
#   (0, 1352)	0.09719772924495604
#   (0, 935)	0.09926309517114014
#   (0, 1294)	0.11365077961708983
#   (0, 1523)	0.11797849794587752
#   (0, 590)	0.12327519710726434
#   (0, 949)	0.12327519710726434
#   (0, 1607)	0.09926309517114014
#   (0, 437)	0.08391427804415212
#   (0, 973)	0.08391427804415212
#   (0, 1604)	0.10682214673513055
#   (0, 1505)	0.12327519710726434
#   (0, 744)	0.10999174590646044
#   (0, 1203)	0.09926309517114014
#   (0, 1579)	0.11797849794587752
#   (0, 774)	0.10682214673513055
#   (0, 1389)	0.11797849794587752
#   (0, 1205)	0.12327519710726434
#   :	:
#   (263, 857)	0.03153514363906969
#   (263, 697)	0.01647546423965999
#   (263, 1593)	0.06307028727813938
#   (263, 1488)	0.01647546423965999
#   (263, 121)	0.015767571819534844
#   (263, 1465)	0.015767571819534844
#   (263, 317)	0.01647546423965999
#   (263, 559)	0.01647546423965999
#   (263, 188)	0.01647546423965999
#   (263, 1773)	0.01647546423965999
#   (263, 248)	0.015189181597994802
#   (263, 1307)	0.03295092847931998
#   (263, 1306)	0.015767571819534844
#   (263, 1270)	0.01647546423965999
#   (263, 465)	0.015767571819534844
#   (263, 355)	0.015767571819534844
#   (263, 1088)	0.01647546423965999
#   (263, 1470)	0.01647546423965999
#   (263, 1154)	0.01647546423965999
#   (263, 1693)	0.01647546423965999
#   (263, 356)	0.015767571819534844
#   (263, 1265)	0.01647546423965999
#   (263, 1264)	0.015767571819534844
#   (263, 283)	0.015767571819534844
#   (263, 454)	0.01647546423965999
