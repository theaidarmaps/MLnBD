# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import string
import re
import nltk
import pymorphy3

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfVectorizer

from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv("petitions.csv")

# %%
df.head()
# Out:
#         id                               public_petition_text  reason_category
# 0  3168490                                     снег на дороге  Благоустройство
# 1  3219678                очистить кабельный киоск от рекламы  Благоустройство
# 2  2963920  Просим убрать все деревья и кустарники, которы...  Благоустройство
# 3  3374910  Неудовлетворительное состояние парадной - надп...   Содержание МКД
# 4  3336285                                           Граффити  Благоустройство

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59889 entries, 0 to 59888
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    59889 non-null  int64
#  1   public_petition_text  59889 non-null  object
#  2   reason_category       59889 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Предарительная обработка данных

# %%
def remove_punctuation(text): 
    return "".join([ch if ch not in string.punctuation else ' ' for ch in text])

def remove_numbers(text): 
    return ''.join([i if not i.isdigit() else ' ' for i in text])

def remove_multiple_spaces(text): 
    return re.sub(r'\s+', ' ', text, flags=re.I)

st = '❯\xa0—«»'
def remove_othersymbol(text):
    return ''.join([ch if ch not in st else ' ' for ch in text])

# %%
df['prep_text'] = [remove_multiple_spaces(remove_numbers(remove_othersymbol(remove_punctuation(text.lower())))) for text in df['public_petition_text']]

# %%
df.head()
# Out:
#         id                               public_petition_text  \
# 0  3168490                                     снег на дороге
# 1  3219678                очистить кабельный киоск от рекламы
# 2  2963920  Просим убрать все деревья и кустарники, которы...
# 3  3374910  Неудовлетворительное состояние парадной - надп...
# 4  3336285                                           Граффити
#
#    reason_category                                          prep_text
# 0  Благоустройство                                     снег на дороге
# 1  Благоустройство                очистить кабельный киоск от рекламы
# 2  Благоустройство  просим убрать все деревья и кустарники которые...
# 3   Содержание МКД  неудовлетворительное состояние парадной надпис...
# 4  Благоустройство                                           граффити

# %%
russian_stopwords = stopwords.words("russian") 
russian_stopwords.extend(['т.д.', 'т', 'д', 'это','который','с','своём','всем','наш', 'свой'])

# %%
def tokenize(text):
    t = word_tokenize(text)
    tokens = [token for token in t if token not in russian_stopwords]
    text = " ".join(tokens)
    return text

# %%
df['tokenize_text'] = [tokenize(text) for text in df['prep_text']]

# %%
df.head()
# Out:
#         id                               public_petition_text  \
# 0  3168490                                     снег на дороге
# 1  3219678                очистить кабельный киоск от рекламы
# 2  2963920  Просим убрать все деревья и кустарники, которы...
# 3  3374910  Неудовлетворительное состояние парадной - надп...
# 4  3336285                                           Граффити
#
#    reason_category                                          prep_text  \
# 0  Благоустройство                                     снег на дороге
# 1  Благоустройство                очистить кабельный киоск от рекламы
# 2  Благоустройство  просим убрать все деревья и кустарники которые...
# 3   Содержание МКД  неудовлетворительное состояние парадной надпис...
# 4  Благоустройство                                           граффити
#
#                                        tokenize_text
# 0                                        снег дороге
# 1                   очистить кабельный киоск рекламы
# 2  просим убрать деревья кустарники которые вышли...
# 3  неудовлетворительное состояние парадной надпис...
# 4                                           граффити

# %%
stemmer = SnowballStemmer("russian")

stem_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = stemmer.stem(word)
            res.append(p)
        text = " ".join(res)
        stem_list.append(text)
    except Exception as e:
        print(e)
        
df['text_stem'] = stem_list

# %%
df.head()
# Out:
#         id                               public_petition_text  \
# 0  3168490                                     снег на дороге
# 1  3219678                очистить кабельный киоск от рекламы
# 2  2963920  Просим убрать все деревья и кустарники, которы...
# 3  3374910  Неудовлетворительное состояние парадной - надп...
# 4  3336285                                           Граффити
#
#    reason_category                                          prep_text  \
# 0  Благоустройство                                     снег на дороге
# 1  Благоустройство                очистить кабельный киоск от рекламы
# 2  Благоустройство  просим убрать все деревья и кустарники которые...
# 3   Содержание МКД  неудовлетворительное состояние парадной надпис...
# 4  Благоустройство                                           граффити
#
#                                        tokenize_text  \
# 0                                        снег дороге
# 1                   очистить кабельный киоск рекламы
# 2  просим убрать деревья кустарники которые вышли...
# 3  неудовлетворительное состояние парадной надпис...
# 4                                           граффити
#
#                                            text_stem
# 0                                         снег дорог
# 1                         очист кабельн киоск реклам
# 2  прос убра дерев кустарник котор вышл предел га...
# 3  неудовлетворительн состоян парадн надпис двер ...
# 4                                            граффит

# %%
morph = pymorphy3.MorphAnalyzer(lang='ru')

# %%
# %%time
lemm_texts_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = morph.parse(word)[0]
            res.append(p.normal_form)
        text = " ".join(res)
        lemm_texts_list.append(text)
    except Exception as e:
        print(e)
    
df['text_lemm'] = lemm_texts_list
# Out:
# CPU times: total: 2min 48s
# Wall time: 2min 50s

# %%
df['text_lemm'] = [tokenize(text) for text in df['text_lemm']]

# %%
df.head()
# Out:
#         id                               public_petition_text  \
# 0  3168490                                     снег на дороге
# 1  3219678                очистить кабельный киоск от рекламы
# 2  2963920  Просим убрать все деревья и кустарники, которы...
# 3  3374910  Неудовлетворительное состояние парадной - надп...
# 4  3336285                                           Граффити
#
#    reason_category                                          prep_text  \
# 0  Благоустройство                                     снег на дороге
# 1  Благоустройство                очистить кабельный киоск от рекламы
# 2  Благоустройство  просим убрать все деревья и кустарники которые...
# 3   Содержание МКД  неудовлетворительное состояние парадной надпис...
# 4  Благоустройство                                           граффити
#
#                                        tokenize_text  \
# 0                                        снег дороге
# 1                   очистить кабельный киоск рекламы
# 2  просим убрать деревья кустарники которые вышли...
# 3  неудовлетворительное состояние парадной надпис...
# 4                                           граффити
#
#                                            text_stem  \
# 0                                         снег дорог
# 1                         очист кабельн киоск реклам
# 2  прос убра дерев кустарник котор вышл предел га...
# 3  неудовлетворительн состоян парадн надпис двер ...
# 4                                            граффит
#
#                                            text_lemm
# 0                                        снег дорога
# 1                   очистить кабельный киоск реклама
# 2  просить убрать дерево кустарник выйти предел г...
# 3  неудовлетворительный состояние парадный надпис...
# 4                                           граффити

# %%
# Получение текстовой строки из списка слов
from wordcloud import WordCloud

def str_corpus(corpus):
    str_corpus = ''
    for i in corpus:
        str_corpus += ' ' + i
    str_corpus = str_corpus.strip()
    return str_corpus

# Получение списка всех слов в корпусе
def get_corpus(data):
    corpus = []
    for phrase in data:
        for word in phrase.split():
            corpus.append(word)
    return corpus

# Получение облака слов
def get_wordCloud(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=russian_stopwords,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(str_corpus(corpus))
    return wordCloud

# %%
corpus = get_corpus(df['reason_category'].values)

# %%
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.imshow(procWordCloud)
plt.axis('off')
plt.title('Облако слов')
plt.show()
plt.close(fig)

# %% [markdown]
# ## Тематическое моделирование

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words=russian_stopwords, ngram_range=(1, 3), min_df=2)
count_matrix = vectorizer.fit_transform(df['text_lemm'])

# %%
from sklearn.decomposition import TruncatedSVD

# %%
# создание модели LSA
lsa_model = TruncatedSVD(n_components=15, random_state=0)
lsa_model.fit(count_matrix)

# вывод топ слов для каждой темы
for i, topic in enumerate(lsa_model.components_):
    print(f"Topic {i}: {', '.join([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]])}")
# Out:
# Topic 0: ru, spb, spb ru, gov spb, gorod, gov, gorod gov spb, gorod gov, gov spb ru, ru problems
# Topic 1: дом, тысяча, этаж, парадный, год, петербург, санкт, санкт петербург, просить, уборка
# Topic 2: этаж, парадный, дом, уборка, дверь, просить, подъезд, мусор, лифт, фото
# Topic 3: xx, xxxxxx, xxx, xxxxx, xxxxxxx, xxxxxxxx, xxxxxxxxx, xxxx, xxxxxxxxxx, xxxxxxxxxxx
# Topic 4: дом, мусор, убрать, газон, территория, фасад, двор, снег, просить, площадка
# Topic 5: мусор, уборка, убрать, график, газон, этаж, площадка, график уборка, производиться, влажный
# Topic 6: дом, парадный, дверь, адрес, двор, просить, мусор, улица, ул, площадка
# Topic 7: дверь, мусор, парадный, убрать, газон, входной, входной дверь, мусор газон, доводчик, просить
# Topic 8: этаж, мусор, фасад, лифт, площадка, стена, здание, первый, освещение, тсж
# Topic 9: парадный, дом, адрес, несанкционированный, объявление, надпись, парадный этаж, двор, освещение, фотофиксация
# Topic 10: парадный, фасад, уборка, мусор, дверь, санкт, санкт петербург, петербург, график, здание
# Topic 11: дом, подъезд, дверь, мусор, этаж, несанкционированный, надпись, объявление, лифт, освещение
# Topic 12: вода, проблема, мусор, горячий, фото, парадный, квартира, горячий вода, площадка, год
# Topic 13: просить, надпись, состояние, площадка, стена, уборка, граффити, просить убрать, надлежащий, привести
# Topic 14: лифт, надпись, убрать, фасад, подъезд, вода, мусор, стена, проблема, работать

# %%
from sklearn.decomposition import NMF

# %%
# создание модели NMF
nmf_model = NMF(n_components=15, random_state=0)
nmf_model.fit(count_matrix)

# вывод топ слов для каждой темы
for i, topic in enumerate(nmf_model.components_):
    print(f"Topic {i}: {', '.join([vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]])}")
# Out:
# Topic 0: ru, spb, spb ru, gov spb ru, gov spb, gov, gorod gov spb, gorod gov, gorod, problems
# Topic 1: тысяча, петербург, санкт, санкт петербург, год, закон, административный, рубль, май, тысяча рубль
# Topic 2: парадный, вход, парадный этаж, стена, ремонт, этаж парадный, состояние, адрес, вход парадный, номер
# Topic 3: xx, xxxxxx, xxx, xxxxx, xxxxxxx, xxxxxxxx, xxxxxxxxx, xxxx, xxxxxxxxxx, xxxxxxxxxxx
# Topic 4: дом, адрес, двор, улица, ул, сторона, дом адрес, проспект, пр, двор дом
# Topic 5: мусор, газон, площадка, убрать, территория, мусор газон, убрать мусор, контейнерный, контейнер, контейнерный площадка
# Topic 6: требоваться, работа, фотофиксация, прилагаться, фотофиксация прилагаться, произвести, требоваться произвести, произвести работа, несанкционированный, качественный
# Topic 7: дверь, входной, подъезд, входной дверь, доводчик, закрываться, замок, состояние, дверь подъезд, дверь парадный
# Topic 8: этаж, первый, лестница, подъезд, стена, первый этаж, лестничный, освещение, отсутствовать, площадка
# Topic 9: уборка, график, подъезд, график уборка, производиться, влажный, графика, влажный уборка, грязь, фото
# Topic 10: снег, убрать, дорога, тротуар, снег дорога, часть, убрать снег, проезжий, проезжий часть, проезд
# Topic 11: фасад, петербург, санкт, санкт петербург, здание, тсж, размещение, благоустройство, решётка, необходимо
# Topic 12: вода, проблема, горячий, квартира, фото, горячий вода, холодный, день, труба, подвал
# Topic 13: просить, состояние, просить убрать, убрать, привести, надлежащий, граффити, неудовлетворительный, произвести, неудовлетворительный состояние
# Topic 14: лифт, работать, грузовой, грузовой лифт, кабина, пассажирский, кнопка, пассажирский лифт, день, ремонт

# %% [markdown]
# ## Векторизация текстовых данных

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=1, max_features=10000000,
                                 min_df=1, stop_words=russian_stopwords,
                                 ngram_range=(1,3))

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text_lemm'])

# %%
tfidf_matrix.shape
# Out:
# (59889, 441544)

# %% [markdown]
# ## Классификация

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, df['reason_category'], test_size=0.2, random_state=42)

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Linear SVC": LinearSVC(),
    "Random Forest": RandomForestClassifier()
}

for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"\n{name} Performance:")
    print(classification_report(y_test, y_pred))
    print(f"Accuracy: {accuracy_score(y_test, y_pred):.4f}")
# Out:
# Logistic Regression Performance:
#                                                                                   precision    recall  f1-score   support
#
#                                                                  Благоустройство       0.58      1.00      0.74      6991
#                                                                    Водоотведение       0.00      0.00      0.00        45
#                                                                    Водоснабжение       0.00      0.00      0.00       169
#                                                                           Кровля       0.00      0.00      0.00       183
#                                   Нарушение порядка пользования общим имуществом       0.00      0.00      0.00        50
#                                    Нарушение правил пользования общим имуществом       0.00      0.00      0.00       398
#                          Незаконная информационная и (или) рекламная конструкция       0.00      0.00      0.00       367
# Незаконная реализация товаров с торгового оборудования (прилавок, ящик, с земли)       0.00      0.00      0.00        46
#                   Повреждения или неисправность элементов уличной инфраструктуры       0.00      0.00      0.00       223
#                                                                          Подвалы       0.00      0.00      0.00        44
#                                                             Санитарное состояние       0.00      0.00      0.00        92
#                                                                   Содержание МКД       0.00      0.00      0.00      2889
#                               Состояние рекламных или информационных конструкций       0.00      0.00      0.00       142
#                                                                            Фасад       0.00      0.00      0.00       280
#                                                            Центральное отопление       0.00      0.00      0.00        59
#
#                                                                         accuracy                           0.58     11978
#                                                                        macro avg       0.04      0.07      0.05     11978
#                                                                     weighted avg       0.34      0.58      0.43     11978
#
# Accuracy: 0.5837
#
# Linear SVC Performance:
#                                                                                   precision    recall  f1-score   support
#
#                                                                  Благоустройство       0.58      1.00      0.74      6991
#                                                                    Водоотведение       0.00      0.00      0.00        45
#                                                                    Водоснабжение       0.00      0.00      0.00       169
#                                                                           Кровля       0.00      0.00      0.00       183
#                                   Нарушение порядка пользования общим имуществом       0.00      0.00      0.00        50
#                                    Нарушение правил пользования общим имуществом       0.00      0.00      0.00       398
#                          Незаконная информационная и (или) рекламная конструкция       0.00      0.00      0.00       367
# Незаконная реализация товаров с торгового оборудования (прилавок, ящик, с земли)       0.00      0.00      0.00        46
#                   Повреждения или неисправность элементов уличной инфраструктуры       0.00      0.00      0.00       223
#                                                                          Подвалы       0.00      0.00      0.00        44
#                                                             Санитарное состояние       0.00      0.00      0.00        92
#                                                                   Содержание МКД       0.00      0.00      0.00      2889
#                               Состояние рекламных или информационных конструкций       0.00      0.00      0.00       142
#                                                                            Фасад       0.00      0.00      0.00       280
#                                                            Центральное отопление       0.00      0.00      0.00        59
#
#                                                                         accuracy                           0.58     11978
#                                                                        macro avg       0.04      0.07      0.05     11978
#                                                                     weighted avg       0.34      0.58      0.43     11978
#
# Accuracy: 0.5837
#
# Random Forest Performance:
#                                                                                   precision    recall  f1-score   support
#
#                                                                  Благоустройство       0.58      1.00      0.74      6991
#                                                                    Водоотведение       0.00      0.00      0.00        45
#                                                                    Водоснабжение       0.00      0.00      0.00       169
#                                                                           Кровля       0.00      0.00      0.00       183
#                                   Нарушение порядка пользования общим имуществом       0.00      0.00      0.00        50
#                                    Нарушение правил пользования общим имуществом       0.00      0.00      0.00       398
#                          Незаконная информационная и (или) рекламная конструкция       0.00      0.00      0.00       367
# Незаконная реализация товаров с торгового оборудования (прилавок, ящик, с земли)       0.00      0.00      0.00        46
#                   Повреждения или неисправность элементов уличной инфраструктуры       0.00      0.00      0.00       223
#                                                                          Подвалы       0.00      0.00      0.00        44
#                                                             Санитарное состояние       0.00      0.00      0.00        92
#                                                                   Содержание МКД       0.00      0.00      0.00      2889
#                               Состояние рекламных или информационных конструкций       0.00      0.00      0.00       142
#                                                                            Фасад       0.00      0.00      0.00       280
#                                                            Центральное отопление       0.00      0.00      0.00        59
#
#                                                                         accuracy                           0.58     11978
#                                                                        macro avg       0.04      0.07      0.05     11978
#                                                                     weighted avg       0.34      0.58      0.43     11978
#
# Accuracy: 0.5837

# %%
import pickle

with open('model_rf.pkl', 'wb') as f:
    pickle.dump(models['Random Forest'], f)

# %%
with open('vectorizer.pkl', 'wb') as f:
    pickle.dump(vectorizer, f)

# %% [markdown]
# ## Парсинг

# %%
from bs4 import BeautifulSoup as bs
import requests
from selenium import webdriver as wd
from selenium.webdriver.edge.service import Service

# %%
path = 'msedgedriver.exe'

# %%
service = Service(path)
options = wd.EdgeOptions()
options.add_argument('--headless')
options.add_argument('--disable-blink-features=AutomationControlled')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = wd.Edge(service = service, options=options)

# %%
url = 'https://vmeste.permkrai.ru/problem/reports?page=1'

# %%
driver.get(url)

# %%
soup = bs(driver.page_source, 'html.parser')

# %%
soup
# Out:
# <html lang="ru"><head><meta content="csrftoken" name="csrf-token-name"/>
# <meta content="184c54e835c1074b215cc811f08f4699363cdf13acdf4597e9745e0cd917247cc868f8a1a12c6438" name="csrf-token-value"/>
# <meta content="Ajax-Token" name="hmac-token-name"/>
# <meta charset="utf-8"/>
# <meta content="msMKxShsruxrtzfncBMCi1sSuHQX04jENS9jg1XK" id="csrf" name="csrf-token"/>
# <script charset="utf-8" src="/649d0e0fe7008120c7149727.js?1750732043543"></script>
# <script>
#       window.appLocale = 'ru';
#       window.appLocaleURL = '';
#     </script>
# <link href="https://vmeste.permkrai.ru/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>Сообщения жителей</title>
# <link href="/build/app.css?v=a29aca9c2b9359547803" rel="stylesheet"/>
# <script defer="" src="/build/runtime.js?v=cd78a093d3505f378abd"></script>
# <script defer="" src="/build/vendors.js?v=395ee2bc85fafe32e79f"></script>
# <script defer="" src="/build/app.js?v=2dad8f6a4ae5903003ab"></script>
# <meta content="app-id=1458156281" name="apple-itunes-app"/>
# <meta content="website" property="og:type"/>
# <meta content="Увидели проблему? Сообщите о ней! Вместе сделаем Пермский край лучше прямо сейчас." name="description"/>
# <meta content="Увидели проблему? Сообщите о ней! Вместе сделаем Пермский край лучше прямо сейчас." property="og:description"/>
# <meta content="Сообщения жителей" property="og:title"/>
# <meta content="https://vmeste.permkrai.ru/problem/reports?page=1" property="og:url"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99997" property="og:image"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99997" property="vk:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Сообщения жителей" name="twitter:title"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99997" name="twitter:image"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99998" property="og:image"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99998" property="vk:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Сообщения жителей" name="twitter:title"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99998" name="twitter:image"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99999" property="og:image"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99999" property="vk:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="Сообщения жителей" name="twitter:title"/>
# <meta content="https://vmeste.permkrai.ru/data/images/sharing/problem/reports/99999" name="twitter:image"/>
# <style>.vue-notification-group{display:block;position:fixed;z-index:5000}.vue-notification-wrapper{display:block;overflow:hidden;width:100%;margin:0;padding:0}.notification-title{font-weight:600}.vue-notification-template{display:block;box-sizing:border-box;background:white;text-align:left}.vue-notification{display:block;box-sizing:border-box;text-align:left;font-size:12px;padding:10px;margin:0 5px 5px;color:#fff;background:#44A4FC;border-left:5px solid #187FE7}.vue-notification.warn{background:#ffb648;border-left-color:#f48a06}.vue-notification.error{background:#E54D42;border-left-color:#b82e24}.vue-notification.success{background:#68CD86;border-left-color:#42a85f}.vn-fade-enter-active,.vn-fade-leave-active,.vn-fade-move{transition:all .5s}.vn-fade-enter-from,.vn-fade-leave-to{opacity:0}</style><script async="" charset="utf-8" src="https://mc.yandex.ru/metrika/tag.js"></script><meta content="width=600, initial-scale=1" name="viewport"/><link href="https://vmeste.permkrai.ru/build/2692.css?v=75326072c04bbf293e16" rel="stylesheet" type="text/css"/><link href="/favicon.ico" rel="icon"/></head>
# <body><noscript><img alt="" height="0" src="/e7bba3a85a3e0c12b3af71a416b766e1.gif" width="0"/></noscript>
# <noscript>
# <div class="browser-error">
# <div class="browser-error__wrapper">
# <div class="browser-error__title">Уважаемый пользователь, ваш браузер заблокировал работу сценариев!</div>
# <div class="browser-error__content">
# <div class="browser-error__text">Для обеспечения полноценной работы портала «Управляем вместе» необходима поддержка JavaScript. Сведения о том, как узнать, поддерживает ли браузер JavaScript, и как включить сценарии, см. в справке браузера.</div>
# </div>
# </div>
# </div>
# </noscript>
# <div data-v-app="" id="app"><div class="app" storedata="[object Object]"><!--v-if--><div class="layout-page-default app__layout" id="layout"><div class="layout-page-default__header"><button class="layout-page-default__toggle ui-svg-button ui-svg-button--big layout-page-default__toggle"><div class="ui-svg-button__wrapper"><svg class="ui-svg ui-svg--up ui-svg-button__svg" version="1.1" viewbox="0 0 40 40"><g transform="translate(-599 -1009)"><rect height="2" rx="1" transform="translate(607 1019)" width="24"></rect><rect height="2" rx="1" transform="translate(607 1025)" width="24"></rect><rect height="2" rx="1" transform="translate(607 1031)" width="24"></rect><rect height="2" rx="1" transform="translate(607 1037)" width="24"></rect></g></svg></div></button><a class="layout-page-default__logo" href="/"><svg class="ui-svg ui-svg--up layout-page-default__logo-image" version="1.1" viewbox="0 0 40 40"><path d="M4 20q0-1.65.3-3.3C5.9 19.3 8.7 21 12 21c5 0 9-4 9-9 0-3.3-1.7-6.1-4.3-7.7Q18.35 4 20 4c2.9 0 5.8.8 8.4 2.3.9.5 2.1.2 2.7-.7.5-.9.2-2.1-.7-2.7C27.3 1 23.7 0 20 0 9 0 0 9 0 20c0 3.7 1 7.3 2.9 10.4.4.7 1 1 1.7 1 .4 0 .8-.1 1.1-.4 1-.5 1.3-1.8.7-2.7C4.8 25.8 4 22.9 4 20m8-13c2.8 0 5 2.2 5 5s-2.2 5-5 5-5-2.2-5-5 2.2-5 5-5m24.9 2.8c-.5-1-1.8-1.3-2.7-.7-1 .5-1.3 1.8-.7 2.7 1.6 2.5 2.4 5.4 2.4 8.3 0 1-.1 2.1-.3 3.1C34 20.7 31.2 19 28 19c-5 0-9 4-9 9 0 3.3 1.7 6.1 4.4 7.7-1.1.2-2.3.4-3.5.4-2.9 0-5.8-.9-8.3-2.4-.9-.5-2.1-.2-2.7.7-.5.9-.2 2.1.7 2.7C12.7 39 16.3 40 20 40c11 0 20-9 20-20 0-3.7-1-7.3-3.1-10.2M28 33c-2.8 0-5-2.2-5-5s2.2-5 5-5 5 2.2 5 5-2.2 5-5 5"></path></svg><div class="layout-page-default__logo-text">Управляем вместе</div></a><div class="layout-page-default__wrapper"><div class="layout-page-default__buttons"><div class="layout-tags layout-page-default__tags"><a class="ui-button ui-button--outlined ui-button--medium ui-button--rounded layout-tags__item" disabled="false" href="/form/main_message" style="--color-accent: 255,85,85;"><div class="ui-button__leading"><svg class="ui-svg ui-svg--up ui-button__icon" version="1.1" viewbox="0 0 24 24"><path d="M19.054 19.067a9.93 9.93 0 0 1-12.39 1.377l-.141-.141a.96.96 0 0 1-.106-1.236 1.015 1.015 0 0 1 1.376-.318A8 8 0 0 0 18.806 7.731 1 1 0 1 1 20.5 6.672a10.046 10.046 0 0 1-1.446 12.395M6.346 6.357a7.96 7.96 0 0 1 9.884-1.13.957.957 0 0 0 1.377-.318.957.957 0 0 0-.318-1.377A9.987 9.987 0 0 0 3.557 17.336l.141.141a.96.96 0 0 0 1.236.106.93.93 0 0 0 .283-1.342 7.965 7.965 0 0 1 1.129-9.884m6.677 6.661V7.023a1 1 0 1 0-2 0v5.993a1 1 0 1 0 2 0Zm-2.5 3.5a1.5 1.5 0 1 0 1.5-1.5 1.5 1.5 0 0 0-1.497 1.493Z"></path></svg></div><div class="ui-button__text">Сообщить о проблеме</div><!--v-if--></a><a aria-current="page" class="router-link-active router-link-exact-active ui-button ui-button--outlined ui-button--medium ui-button--rounded layout-tags__item" disabled="false" href="/problem/reports" style="--color-accent: 127,139,148;"><!--v-if--><div class="ui-button__text">Сообщения</div><!--v-if--></a><a class="ui-button ui-button--outlined ui-button--medium ui-button--rounded layout-tags__item layout-tags__item--hidden" disabled="false" href="/ratings/users" style="--color-accent: 127,139,148;"><!--v-if--><div class="ui-button__text">Рейтинг пользователей</div><!--v-if--></a></div><button class="layout-page-default__search-button ui-svg-button ui-svg-button--big layout-page-default__search-button"><div class="ui-svg-button__wrapper"><svg class="ui-svg ui-svg--up ui-svg-button__svg" version="1.1" viewbox="0 0 40 40"><path d="m30.035 31.487-4.873-4.867a10.487 10.487 0 1 1 1.455-1.453l4.869 4.869a1 1 0 0 1 0 1.412l-.039.039a.99.99 0 0 1-1.412 0M10.004 18.505a8.5 8.5 0 1 0 8.5-8.5 8.51 8.51 0 0 0-8.5 8.499Z"></path></svg></div></button><div class="ui-popover layout-share layout-page-default__share"><div class="ui-popover__trigger"><button class="layout-share__button ui-svg-button ui-svg-button--big layout-share__button"><div class="ui-svg-button__wrapper"><svg class="ui-svg ui-svg--up ui-svg-button_ ...
# Щебень был выгружен в конце улицы и больше ничего не сделано. В дождь каша.</div><!--v-if--><div class="ui-gallery problem-report__photos"><div class="ui-gallery__previews"><div class="ui-gallery__preview"><div class="ui-spinner ui-spinner--round ui-spinner--medium ui-spinner--overlay ui-image ui-gallery__preview-image"><img alt="undefined: фотография" class="ui-image__image" src="https://vmeste.permkrai.ru/data/images/comments/thumbs/1ae9f7819fb714dba1e1eea4c9790fb3.jpg"/></div><button class="ui-gallery__preview-button"></button></div><div class="ui-gallery__preview"><div class="ui-spinner ui-spinner--round ui-spinner--medium ui-spinner--overlay ui-image ui-gallery__preview-image"><img alt="undefined: фотография" class="ui-image__image" src="https://vmeste.permkrai.ru/data/images/comments/thumbs/30c7e11bc1656ecb15fc8a6eb9d27743.jpg"/></div><button class="ui-gallery__preview-button"></button></div></div><!--v-if--></div><!--v-if--><!--v-if--><!--v-if--><!--v-if--><!--v-if--></div></div><!--v-if--></div><!--v-if--></div><div class="problem-reports__children"></div></div><div class="problem-reports problem-reports--chain problem-page-reports__item" data-comment-id="2042158" style="--problem-reports-line-top: 161px; --problem-reports-line-height: 0px;"><div class="problem-reports__parent"><div class="problem-report problem-reports__body" data-comment-id="2042158" id="false" style="--problem-report-status-color: 245,168,73;"><div class="problem-report__header"><div class="problem-report__line"><a class="link problem-report__title" href="/problem/reports/729225">Сообщение №729225</a><div class="tag problem-report__status">Готовится ответ</div></div><div class="problem-report__line"><div class="problem-report__category"><svg class="ui-svg ui-svg--up problem-report__category-icon" version="1.1" viewbox="0 0 20 20"><path d="M15 8c-1.6 0-3.1.8-4 2l.9-6h.1c.5 0 1-.5 1-1s-.5-1-1-1H6c-.5 0-1 .5-1 1v5H4V6.8c-.1-1-1-1.7-2-1.8-.5 0-1 .5-1 1s.5 1 1 1v1c-1.1 0-2 .9-2 2v4c0 .8.5 1.4 1.1 1.8C1.4 17.1 2.6 18 4 18c1.3 0 2.4-.8 2.8-2H9c.5 0 1-.5 1-1s-.5-1-1-1H6.8c-.4-1.2-1.5-2-2.8-2-.8 0-1.5.3-2 .8V10h3.8c.5.6 1.3 1 2.2 1h2c.2 0 .3 0 .5-.1-.2.3-.3.7-.4 1.1H9c-.5 0-1 .5-1 1s.5 1 1 1h1.1c.5 2.3 2.5 4 4.9 4 2.8 0 5-2.2 5-5s-2.2-5-5-5M4 14c.5 0 1 .5 1 1s-.5 1-1 1-1-.5-1-1 .5-1 1-1m5.1-5H8c-.5 0-1-.5-1-1V4h2.8zm5.9 7c-1.3 0-2.4-.8-2.8-2H15c.5 0 1-.5 1-1s-.5-1-1-1h-2.8c.4-1.2 1.5-2 2.8-2 1.7 0 3 1.3 3 3s-1.3 3-3 3"></path></svg><div class="problem-report__category-text">Дороги / Некачественное содержание светофоров</div><div class="problem-page-residents problem-page-residents--view-only"><div class="ui-popover"><div class="ui-popover__trigger"><div class="problem-page-residents__list"><!--v-if--></div></div></div></div></div><div class="problem-report__additional-info"><div class="problem-report__address"><svg class="ui-svg ui-svg--up problem-report__address-icon" version="1.1" viewbox="0 0 24 24"><path d="M11.281 21.756c-.277-.24-6.891-5.984-6.891-12.176a7.545 7.545 0 1 1 15.09 0c0 6.191-6.615 11.936-6.891 12.176a1 1 0 0 1-1.309 0ZM6.381 9.58c0 4.238 3.955 8.512 5.547 10.053 1.592-1.549 5.547-5.822 5.547-10.053a5.547 5.547 0 1 0-11.094 0m2.045-.021a3.438 3.438 0 1 1 3.438 3.439 3.44 3.44 0 0 1-3.433-3.439Zm2 0a1.437 1.437 0 1 0 1.436-1.436 1.44 1.44 0 0 0-1.429 1.436Z"></path></svg><div class="problem-report__address-text">Пермь ГО, Ласьвинская улица, 37А</div></div></div></div></div><div class="ui-spinner ui-spinner--round ui-spinner--medium ui-spinner--overlay problem-report__body"><div class="problem-report__info"><div class="problem-report__date">25.06.2025 18:11</div><!--v-if--><!--v-if--></div><div class="problem-report__author-wrapper"><div class="problem-report__author"><div class="ui-spinner ui-spinner--round ui-spinner--small ui-spinner--overlay app-user-avatar problem-report__avatar"><div class="app-user-avatar__placeholder" style="--app-user-avatar-placeholder-color: #bcd9eb;">ВН</div></div><div class="problem-report__wrapper"><a class="lin ...
# </body></html>

# %%
with open('vectorizer.pkl', 'rb') as f:
    tfidf = pickle.load(f)

with open('model_rf.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
pagenum = 1

for i in range(1,60):
    url = f'https://vmeste.permkrai.ru/problem/reports?page={pagenum}'
    print(f'страница {pagenum}')
    driver.get(url)
    soup = bs(driver.page_source, 'html.parser')
    problems = soup.find_all('div', class_='problem-report problem-reports__body')
    
    for problem in problems:
        problem_id = problem.find('a', class_='link problem-report__title')
        problem_category = problem.find('div', class_='problem-report__category-text')
        problem_text = problem.find('div', class_='problem-report__text')
        new_row = {"id": problem_id.text.split('№')[1], "public_petition_text": problem_text.text,
                  "reason_category": problem_category.text.split(' / ')[0]}
        df.loc[len(df)] = new_row
    pagenum += 1
driver.close()
# Out:
# страница 1
# страница 2
# страница 3
# страница 4
# страница 5
# страница 6
# страница 7
# страница 8
# страница 9
# страница 10
# страница 11
# страница 12
# страница 13
# страница 14
# страница 15
# страница 16
# страница 17
# страница 18
# страница 19
# страница 20
# страница 21
# страница 22
# страница 23
# страница 24
# страница 25
# страница 26
# страница 27
# страница 28
# страница 29
# страница 30
# страница 31
# страница 32
# страница 33
# страница 34
# страница 35
# страница 36
# страница 37
# страница 38
# страница 39
# страница 40
# страница 41
# страница 42
# страница 43
# страница 44
# страница 45
# страница 46
# страница 47
# страница 48
# страница 49
# страница 50
# страница 51
# страница 52
# страница 53
# страница 54
# страница 55
# страница 56
# страница 57
# страница 58
# страница 59

# %%
df
# Out:
#             id                               public_petition_text  \
# 0      3168490                                     снег на дороге
# 1      3219678                очистить кабельный киоск от рекламы
# 2      2963920  Просим убрать все деревья и кустарники, которы...
# 3      3374910  Неудовлетворительное состояние парадной - надп...
# 4      3336285                                           Граффити
# ...        ...                                                ...
# 60474   728016  Незаконная расклейка объявлений на опоре ВЛ 11...
# 60475   728015  Незаконная расклейка объявлений на светофорной...
# 60476   728014  Незаконная расклейка объявлений. Координаты 57...
# 60477   728013  Незаконная расклейка объявлений на фасаде. Коо...
# 60478   728012  Не работает вся линия освещения от остановки П...
#
#              reason_category  \
# 0            Благоустройство
# 1            Благоустройство
# 2            Благоустройство
# 3             Содержание МКД
# 4            Благоустройство
# ...                      ...
# 60474  Рекламные конструкции
# 60475  Рекламные конструкции
# 60476  Рекламные конструкции
# 60477  Рекламные конструкции
# 60478      Уличное освещение
#
#                                                prep_text  \
# 0                                         снег на дороге
# 1                    очистить кабельный киоск от рекламы
# 2      просим убрать все деревья и кустарники которые...
# 3      неудовлетворительное состояние парадной надпис...
# 4                                               граффити
# ...                                                  ...
# 60474  незаконная расклейка объявлений на опоре вл кв...
# 60475  незаконная расклейка объявлений на светофорной...
# 60476        незаконная расклейка объявлений координаты
# 60477  незаконная расклейка объявлений на фасаде коор...
# 60478  не работает вся линия освещения от остановки п...
#
#                                            tokenize_text  \
# 0                                            снег дороге
# 1                       очистить кабельный киоск рекламы
# 2      просим убрать деревья кустарники которые вышли...
# 3      неудовлетворительное состояние парадной надпис...
# 4                                               граффити
# ...                                                  ...
# 60474  незаконная расклейка объявлений опоре вл кв ко...
# 60475  незаконная расклейка объявлений светофорной ст...
# 60476         незаконная расклейка объявлений координаты
# 60477  незаконная расклейка объявлений фасаде координаты
# 60478  работает вся линия освещения остановки парма н...
#
#                                                text_stem  \
# 0                                             снег дорог
# 1                             очист кабельн киоск реклам
# 2      прос убра дерев кустарник котор вышл предел га...
# 3      неудовлетворительн состоян парадн надпис двер ...
# 4                                                граффит
# ...                                                  ...
# 60474     незакон расклейк объявлен опор вл кв координат
# 60475  незакон расклейк объявлен светофорн стойк коор...
# 60476                незакон расклейк объявлен координат
# 60477          незакон расклейк объявлен фасад координат
# 60478  работа вся лин освещен остановк парм нача спус...
#
#                                                text_lemm
# 0                                            снег дорога
# 1                       очистить кабельный киоск реклама
# 2      просить убрать дерево кустарник выйти предел г...
# 3      неудовлетворительный состояние парадный надпис...
# 4                                               граффити
# ...                                                  ...
# 60474                                                NaN
# 60475                                                NaN
# 60476                                                NaN
# 60477                                                NaN
# 60478                                                NaN
#
# [60479 rows x 7 columns]

# %%
# %%time
lemm_texts_list = []
for text in (df['tokenize_text']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = morph.parse(word)[0]
            res.append(p.normal_form)
        text = " ".join(res)
        lemm_texts_list.append(text)
    except Exception as e:
        print(e)
    
df['text_lemm'] = lemm_texts_list

df['text_lemm'] = [tokenize(text) for text in df['text_lemm']]
# Out:
# CPU times: total: 1min 20s
# Wall time: 1min 21s

# %%
X_train = tfidf.fit_transform(df['text_lemm'])
y_train = df['reason_category']

model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

with open(f'updated_model.pkl', 'wb') as f:
    pickle.dump(model, f)

with open(f'updated_vectorizer.pkl', 'wb') as f:
    pickle.dump(tfidf, f)
