# %% [markdown]
# #### 1 Создание фрейма данных

# %%
import numpy as np
import pandas as pd

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\robhul\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\robhul\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\robhul\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\robhul\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\robhul\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\robhul\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Ядром pandas являются две структуры данных, в которых происходят все операции: Series и DataFrames.

# %% [markdown]
# Series — это объект библиотеки pandas, спроектированный для представления одномерных структур данных, похожих на массивы, но с дополнительными возможностями. Его структура проста, ведь он состоит из двух связанных между собой массивов. Основной содержит данные (данные любого типа NumPy), а в дополнительном, index, хранятся метки.

# %% [markdown]
# #### Создание объекта Series

# %% [markdown]
# Для создания объекта Series необходимо вызвать конструктор Series() и передать в качестве аргумента массив, содержащий значения, которые необходимо включить.

# %%
letters = ['a', 'b', 'c']
numbers = [1, 2, 3]
arr = np.array(numbers)
dict = {'a':1, 'b':2, 'c':3}

# %%
pd.Series(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(data=numbers, index=letters)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(numbers, letters)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
pd.Series(dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %% [markdown]
# Если объект Series — аналог одномерного массива с гибкими индексами, объект DataFrame — аналог двумерного массива с гибкими индексами строк и гибкими именами столбцов. Аналогично тому, что двумерный массив можно рассматривать как упорядоченную последовательность выровненных столбцов, объект DataFrame можно рассматривать как упорядоченную последовательность выровненных объектов Series. Под «выровненными» имеется в виду то, что они используют один и тот же индекс.

# %% [markdown]
# #### Создание объекта DataFrame

# %%
df = pd.DataFrame(np.random.randn(4, 5), [1, 2, 3, 4], ['red', 'orange', 'yellow', 'green', 'blue'])

# %%
df
# Out:
#         red    orange    yellow     green      blue
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314
# 3  1.035020 -0.161850 -0.452054  0.137250  0.527517
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243

# %%
df.columns
# Out:
# Index(['red', 'orange', 'yellow', 'green', 'blue'], dtype='object')

# %%
df.index
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %%
df['orange']
# Out:
# 1   -1.424615
# 2    0.720195
# 3   -0.161850
# 4    1.216484
# Name: orange, dtype: float64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['orange'])
# Out:
# pandas.core.series.Series

# %%
df[['yellow', 'blue']]
# Out:
#      yellow      blue
# 1  0.637510 -0.306042
# 2 -0.321762  0.762314
# 3 -0.452054  0.527517
# 4 -1.504190  1.370243

# %%
df['indigo'] = df['blue']

# %%
df
# Out:
#         red    orange    yellow     green      blue    indigo
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314
# 3  1.035020 -0.161850 -0.452054  0.137250  0.527517  0.527517
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243

# %%
df['violet'] = df['blue'] + df['indigo']

# %%
df
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3  1.035020 -0.161850 -0.452054  0.137250  0.527517  0.527517  1.055034
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %% [markdown]
# #### Навигация по фреймам данных

# %% [markdown]
# Для выбора одной или нескольких строк либо значений использовать методы lос или iloc. Все строки во фрейме данных pandas имеют уникальное индексное значение. По умолчанию этот индекс является целым числом, указывающим на положение строки во фрейме данных; однако это не обязательно. Метод lос полезен, когда индекс фрейма является меткой (например, строковым значением). Метод iloc работает, отыскивая позицию во фрейме данных (по номеру индекса).

# %%
df.loc[2]
# Out:
# red      -0.810816
# orange    0.720195
# yellow   -0.321762
# green     2.523070
# blue      0.762314
# indigo    0.762314
# violet    1.524628
# Name: 2, dtype: float64

# %%
df.iloc[1]
# Out:
# red      -0.810816
# orange    0.720195
# yellow   -0.321762
# green     2.523070
# blue      0.762314
# indigo    0.762314
# violet    1.524628
# Name: 2, dtype: float64

# %%
df.iloc[2] = df.iloc[1]

# %%
df
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df.loc[3, 'orange']
# Out:
# 0.7201953350384038

# %%
df.iloc[2, 1]
# Out:
# 0.7201953350384038

# %%
df.loc[[1,3], ['blue', 'violet']]
# Out:
#        blue    violet
# 1 -0.306042 -0.612084
# 3  0.762314  1.524628

# %% [markdown]
# #### Выбор строк на основе условных конструкций

# %%
df[df > 0]
# Out:
#         red    orange   yellow     green      blue    indigo    violet
# 1  0.700591       NaN  0.63751  0.549817       NaN       NaN       NaN
# 2       NaN  0.720195      NaN  2.523070  0.762314  0.762314  1.524628
# 3       NaN  0.720195      NaN  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484      NaN       NaN  1.370243  1.370243  2.740487

# %%
df['yellow'] > 0
# Out:
# 1     True
# 2    False
# 3    False
# 4    False
# Name: yellow, dtype: bool

# %%
df[df['yellow']<0]
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df[df['yellow']<0]['green']
# Out:
# 2    2.523070
# 3    2.523070
# 4   -0.174056
# Name: green, dtype: float64

# %%
df[df['yellow']<0][['green','blue']]
# Out:
#       green      blue
# 2  2.523070  0.762314
# 3  2.523070  0.762314
# 4 -0.174056  1.370243

# %%
df[(df['blue']>0) & (df['yellow']<0)]
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df[(df['blue']>0) | (df['yellow']<0)]
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %% [markdown]
# #### Удаление строк

# %%
# удаление строк axis = 0 столбец axis = 1  inplace=False без удаления из датафрейма, inplace=True с удалением
df.drop(3)
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 3 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df.drop(3, inplace = True)

# %%
df
# Out:
#         red    orange    yellow     green      blue    indigo    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  1.370243  2.740487

# %%
df.drop('indigo', axis = 1, inplace = True)

# %%
df
# Out:
#         red    orange    yellow     green      blue    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628
# 4  1.085780  1.216484 -1.504190 -0.174056  1.370243  2.740487

# %% [markdown]
# ####  Удаление повторяющихся строк

# %% [markdown]
# Метод drop_duplicates() по умолчанию отбрасывает только те строки, которые идеально совпадают по всем столбцам.

# %%
df.iloc[2] = df.iloc[1]

# %%
df
# Out:
#         red    orange    yellow     green      blue    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628
# 4 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628

# %%
# Удалить дубликаты, показать строки  
df.drop_duplicates().head()
# Out:
#         red    orange    yellow     green      blue    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628

# %%
df
# Out:
#         red    orange    yellow     green      blue    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628
# 4 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628

# %%
df = df.drop_duplicates().head()

# %%
df
# Out:
#         red    orange    yellow     green      blue    violet
# 1  0.700591 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628

# %% [markdown]
# Чтобы выполнить проверку на наличие повторяющихся строк, нередко требуется рассмотреть только подмножество столбцов. Это можно сделать с помощью параметра subset. Метод drop_duplicates по умолчанию сохраняет первое появление повторяющейся строки и удаляет остальные

# %%
df.loc[1,'red'] = df.loc[2,'red']

# %%
df
# Out:
#         red    orange    yellow     green      blue    violet
# 1 -0.810816 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.810816  0.720195 -0.321762  2.523070  0.762314  1.524628

# %%
df.drop_duplicates(subset=['red'])
# Out:
#         red    orange   yellow     green      blue    violet
# 1 -0.810816 -1.424615  0.63751  0.549817 -0.306042 -0.612084

# %% [markdown]
# #### Замена значений

# %%
df['orange'].mean()
# Out:
# -0.35221003459956

# %%
# Заменить значения 
df['red'].replace(df.loc[1, 'red'],df['orange'].mean(), inplace=True)
# Out:
# C:\Users\robhul\AppData\Local\Temp\ipykernel_9800\3680650645.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['red'].replace(df.loc[1, 'red'],df['orange'].mean(), inplace=True)

# %%
df
# Out:
#        red    orange    yellow     green      blue    violet
# 1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628

# %% [markdown]
# #### Работа с индексами

# %% [markdown]
# reset_index() — это метод сброса индекса фрейма данных. Метод .reset_index () задает список целых чисел от 0 до длины данных в качестве индекса.

# %%
df.reset_index()
# inplace = True
# Out:
#    index      red    orange    yellow     green      blue    violet
# 0      1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 1      2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628

# %%
z1 = [2, 3]
df['Z1'] = z1

# %%
df
# Out:
#        red    orange    yellow     green      blue    violet  Z1
# 1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084   2
# 2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628   3

# %%
df.set_index('Z1')
# Out:
#         red    orange    yellow     green      blue    violet
# Z1
# 2  -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084
# 3  -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628

# %% [markdown]
# #### Переименование столбцов

# %%
# Переименовать столбец, показать две строки
df.rename(columns={'red': 'Red'}).head()
# Out:
#        Red    orange    yellow     green      blue    violet  Z1
# 1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084   2
# 2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628   3

# %%
df
# Out:
#        red    orange    yellow     green      blue    violet  Z1
# 1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084   2
# 2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628   3

# %%
df.rename(columns={'red': 'Red'}, inplace=True)

# %%
df
# Out:
#        Red    orange    yellow     green      blue    violet  Z1
# 1 -0.35221 -1.424615  0.637510  0.549817 -0.306042 -0.612084   2
# 2 -0.35221  0.720195 -0.321762  2.523070  0.762314  1.524628   3
