# %% [markdown]
# ## Импорт библиотек

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# ## Загрузка данных

# %%
df = pd.read_csv('car_sales_data.csv')

# %%
df.head()
# Out:
#   Manufacturer       Model  Engine size Fuel type  Year of manufacture  \
# 0         Ford      Fiesta          1.0    Petrol                 2002
# 1      Porsche  718 Cayman          4.0    Petrol                 2016
# 2         Ford      Mondeo          1.6    Diesel                 2014
# 3       Toyota        RAV4          1.8    Hybrid                 1988
# 4           VW        Polo          1.0    Petrol                 2006
#
#    Mileage  Price
# 0   127300   3074
# 1    57850  49704
# 2    39190  24072
# 3   210814   1705
# 4   127869   4101

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         50000 non-null  str
#  1   Model                50000 non-null  str
#  2   Engine size          50000 non-null  float64
#  3   Fuel type            50000 non-null  str
#  4   Year of manufacture  50000 non-null  int64
#  5   Mileage              50000 non-null  int64
#  6   Price                50000 non-null  int64
# dtypes: float64(1), int64(3), str(3)
# memory usage: 2.7 MB

# %%
df.duplicated().sum()
# Out:
# np.int64(12)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Данные содержат следующие столбцы:
# - __Manufacturer__ (Производитель): Марка или компания, производящая автомобиль.
# - __Model__ (Модель): Конкретная модель автомобиля.
# - __Engine size__ (Объем двигателя): Объем двигателя в литрах.
# - __Fuel type__ (Тип топлива): Тип топлива, используемого автомобилем (бензин, дизель, гибрид, электромобиль).
# - __Year of manufacture__ (Год выпуска): Год выпуска автомобиля.
# - __Mileage__ (Пробег): Общее расстояние, пройденное автомобилем, измеренное в милях.
# - __Price__ (Цена): Цена продажи автомобиля в фунтах стерлингов (приблизительные значения).

# %%
df.describe()
# Out:
#         Engine size  Year of manufacture        Mileage          Price
# count  49988.000000         49988.000000   49988.000000   49988.000000
# mean       1.773140          2004.209630  112515.561215   13829.112387
# std        0.734149             9.646056   71624.341062   16417.812203
# min        1.000000          1984.000000     630.000000      76.000000
# 25%        1.400000          1996.000000   54375.250000    3059.750000
# 50%        1.600000          2004.000000  101011.500000    7971.000000
# 75%        2.000000          2012.000000  158617.250000   19028.500000
# max        5.000000          2022.000000  453537.000000  168081.000000

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'Engine size'}>,
#         <Axes: title={'center': 'Year of manufacture'}>],
#        [<Axes: title={'center': 'Mileage'}>,
#         <Axes: title={'center': 'Price'}>]], dtype=object)

# %%
plt.figure(figsize=(8,6))
sns.pairplot(df)

# %%
plt.figure(figsize=(10,5))
sns.histplot(df['Price'], bins=80, kde=True, color='teal')
plt.title('Price')
plt.show()

# %%
cols = ['Engine size','Year of manufacture','Mileage']
plt.figure(figsize=(8,4))
for col in cols:
    plt.subplot(1,3,cols.index(col)+1)
    sns.histplot(df[col],bins=30,kde=True,color='teal')
    plt.title(col)
plt.tight_layout()

# %% [markdown]
# ## Обучение

# %%
df['CarAge'] = 2026 - df['Year of manufacture']
df.drop(columns=['Year of manufacture'],inplace=True)

# %%
numeric_cols = ['Mileage','CarAge']

scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df = pd.get_dummies(df,columns=['Model'],drop_first=True,dtype=int)

# %%
manufacturer = {
    'VW': 0,
    'Ford': 1,
    'Toyota': 2,
    'BMW': 3,
    'Porsche': 4,
}
df['Manufacturer'] = df['Manufacturer'].map(manufacturer)

# %%
fuel = {
    'Diesel': 0,
    'Petrol': 1,
    'Hybrid': 2
}
df['Fuel type'] = df['Fuel type'].map(fuel)

# %%
X = df.drop('Price',axis=1)
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.25,
    random_state=42
)

# %% [markdown]
# ### Линейная регрессия

# %%
lr_model = LinearRegression()
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr = lr_model.predict(X_test)

# %%
lr_mae = mean_absolute_error(y_test, y_pred_lr)
lr_rmse = np.sqrt(mean_squared_error(y_test, y_pred_lr))
lr_r2 = r2_score(y_test, y_pred_lr)

# %%
print('Linear Regression:')
print(f'R2 Score: {lr_r2:.4f}')
print(f'MAE: {lr_mae:.2f}')
print(f'RMSE: {lr_rmse:.2f}')
# Out:
# Linear Regression:
# R2 Score: 0.7142
# MAE: 5737.31
# RMSE: 8715.52

# %% [markdown]
# ### Random Forest Regressor

# %%
rf_model = RandomForestRegressor(
    n_estimators=100,
    max_depth=None,
    min_samples_split=2,
    min_samples_leaf=1,
    random_state=42
)

rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %%
rf_r2_score = r2_score(y_test, y_pred_rf)
rf_mae = mean_absolute_error(y_test, y_pred_rf)
rf_rmse = np.sqrt(mean_squared_error(y_test,y_pred_rf))

print('Random Forest Regression:')
print(f'R2 Score: {rf_r2_score:.4f}')
print(f'MAE: {rf_mae:.2f}')
print(f'RMSE: {rf_rmse:.2f}')
# Out:
# Random Forest Regression:
# R2 Score: 0.9984
# MAE: 291.88
# RMSE: 659.48

# %% [markdown]
# ### Нейронная модель

# %%
scaler_X = StandardScaler()
scaler_y = StandardScaler()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)


X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=101
)

X_train_scaled = scaler_X.fit_transform(X_train)
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).flatten()

X_test_scaled = scaler_X.transform(X_test)
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)).flatten()

X_val_scaled = scaler_X.transform(X_val)
y_val_scaled = scaler_y.transform(y_val.values.reshape(-1, 1)).flatten()

# %%
input_shape = X_train_scaled.shape[1]

nn_model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(input_shape,)),
    layers.BatchNormalization(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(32, activation='relu'),
    layers.Dense(1)
])

nn_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = nn_model.fit(
    X_train_scaled, y_train_scaled,
    validation_split=0.15,
    epochs=40,
    batch_size=512,
    verbose=1,
    callbacks=[keras.callbacks.EarlyStopping(patience=8, restore_best_weights=True)]
)
# Out:
# Epoch 1/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3762 - mae: 0.3839 - val_loss: 0.5145 - val_mae: 0.4949
# Epoch 2/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1130 - mae: 0.2167 - val_loss: 0.4539 - val_mae: 0.4607
# Epoch 3/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0743 - mae: 0.1754 - val_loss: 0.3270 - val_mae: 0.3982
# Epoch 4/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0567 - mae: 0.1508 - val_loss: 0.2738 - val_mae: 0.3585
# Epoch 5/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0471 - mae: 0.1393 - val_loss: 0.1846 - val_mae: 0.2952
# Epoch 6/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0423 - mae: 0.1295 - val_loss: 0.1065 - val_mae: 0.2327
# Epoch 7/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0373 - mae: 0.1216 - val_loss: 0.0752 - val_mae: 0.1911
# Epoch 8/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0343 - mae: 0.1147 - val_loss: 0.0480 - val_mae: 0.1505
# Epoch 9/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0303 - mae: 0.1099 - val_loss: 0.0193 - val_mae: 0.1033
# Epoch 10/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0286 - mae: 0.1026 - val_loss: 0.0277 - val_mae: 0.1117
# Epoch 11/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0256 - mae: 0.0993 - val_loss: 0.0143 - val_mae: 0.0838
# Epoch 12/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0280 - mae: 0.1014 - val_loss: 0.0246 - val_mae: 0.0893
# Epoch 13/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0241 - mae: 0.0948 - val_loss: 0.0212 - val_mae: 0.0886
# Epoch 14/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231 - mae: 0.0920 - val_loss: 0.0101 - val_mae: 0.0699
# Epoch 15/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0230 - mae: 0.0905 - val_loss: 0.0207 - val_mae: 0.0864
# Epoch 16/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0187 - mae: 0.0844 - val_loss: 0.0096 - val_mae: 0.0652
# Epoch 17/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0202 - mae: 0.0851 - val_loss: 0.0107 - val_mae: 0.0679
# Epoch 18/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191 - mae: 0.0835 - val_loss: 0.0158 - val_mae: 0.0814
# Epoch 19/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0150 - mae: 0.0760 - val_loss: 0.0327 - val_mae: 0.1032
# Epoch 20/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0198 - mae: 0.0820 - val_loss: 0.0546 - val_mae: 0.1252
# Epoch 21/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0168 - mae: 0.0772 - val_loss: 0.0097 - val_mae: 0.0708
# Epoch 22/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0160 - mae: 0.0774 - val_loss: 0.0159 - val_mae: 0.0837
# Epoch 23/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0154 - mae: 0.0752 - val_loss: 0.0075 - val_mae: 0.0657
# Epoch 24/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0149 - mae: 0.0741 - val_loss: 0.0251 - val_mae: 0.0960
# Epoch 25/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - mae: 0.0758 - val_loss: 0.0142 - val_mae: 0.0804
# Epoch 26/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148 - mae: 0.0724 - val_loss: 0.0276 - val_mae: 0.1042
# Epoch 27/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132 - mae: 0.0692 - val_loss: 0.0185 - val_mae: 0.0927
# Epoch 28/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0125 - mae: 0.0687 - val_loss: 0.0112 - val_mae: 0.0734
# Epoch 29/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0123 - mae: 0.0674 - val_loss: 0.0172 - val_mae: 0.0914
# Epoch 30/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0147 - mae: 0.0723 - val_loss: 0.0136 - val_mae: 0.0850
# Epoch 31/40
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136 - mae: 0.0694 - val_loss: 0.0192 - val_mae: 0.0931

# %%
y_pred_scaled = nn_model.predict(X_test_scaled).flatten()

y_pred_scaled
# Out:
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 578us/step
# array([-0.5997702 , -0.57395697, -0.7041061 , ..., -0.20582592,
#        -0.32441583, -0.52755076], shape=(14997,), dtype=float32)

# %%
y_pred = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()
y_test_original = scaler_y.inverse_transform(y_test_scaled.reshape(-1, 1)).flatten()

# %%
nn_pred = nn_model.predict(X_train_scaled, verbose=0).flatten()

# %%
nn_mae = mean_absolute_error(y_test, y_pred)
nn_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
nn_r2 = r2_score(y_test, y_pred)

print('Neural model:')
print(f'R2 Score: {nn_r2:.4f}')
print(f'MAE: {nn_mae:.2f}')
print(f'RMSE: {nn_rmse:.2f}')
# Out:
# Neural model:
# R2 Score: 0.9925
# MAE: 1053.76
# RMSE: 1392.73

# %%
results = {
    'Нейронная сеть': {
        'r2': nn_r2,
        'MAE': nn_mae,
        'RMSE': nn_rmse,
    },
    'Random Forest': {
        'r2': rf_r2_score,
        'MAE': rf_mae,
        'RMSE': rf_rmse,
    },
    'Linear Regression': {
        'r2': lr_r2,
        'MAE': lr_mae,
        'RMSE': lr_rmse,
    }
}

# Визуализация
fig, axes = plt.subplots(1, 3, figsize=(12, 5))

# r2
r2_list = [results[model]['r2'] for model in results.keys()]
axes[0].bar(results.keys(), r2_list,)
axes[0].set_title('R2-Score')


# mae
mae_list = [results[model]['MAE'] for model in results.keys()]
axes[1].bar(results.keys(), mae_list)
axes[1].set_title('MAE')

# rmse
rmse_list = [results[model]['RMSE'] for model in results.keys()]
axes[2].bar(results.keys(), rmse_list)
axes[2].set_title('RMSE')


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Вывод:
#
# Этот проект успешно демонстрирует практическое применение машинного обучения для прогнозирования цен на подержанные автомобили со значительной точностью. Разработанная модель эффективно отражает сложные взаимосвязи между техническими характеристиками автомобиля и рыночной стоимостью, при этом ключевые факторы включают возраст автомобиля, пробег, марку производителя и характеристики двигателя. Внедрение функционального инжиниринга — создание новых переменных, таких как возраст автомобиля, годовой пробег и флаги люксовых брендов, — оказалось решающим фактором повышения производительности модели и ее интерпретируемости.
#
# Random Forest Regressor показал лучший R² (0.9984).
